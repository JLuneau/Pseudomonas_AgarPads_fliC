# %% [markdown]
# # Run Delta segmentation & tracking pipeline
#
# Here we will use the Delta2 package to segment and track timelapse data of microcolonies using a deep learning based workflow.
# You can find extensive documentation on Delta [here](https://delta.readthedocs.io).
#
# In addition we will need the `json` package to edit the configuration files.

# %%
import pathlib
import delta
import json

# %% [markdown]
# Deep Learning networks can run on a CPU, but are much much faster on a GPU.
# Let's see if we can use a GPU (you should see get a line with `device_type='GPU'):

# %%
import tensorflow as tf
tf.config.list_physical_devices()
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'),
#  PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ---

# %% [markdown]
# ## Setup Folders
# Set the path to the one you used in `0_download_model_delta`.
# We will also create a `ProcessedData` folder where we will store the output

# %%
root = pathlib.Path(pathlib.Path.home(), 'Documents/Image_analysis/Pseudomonas/2023.09.27_Psy_AgarPads#13')
strain_dir = (root / 'Psy-eGFP') 
model_dir = strain_dir / 'models' #location of model

# !ls $strain_dir
# Out:
# 0_Run_delta_pipeline_Psy.ipynb   2023.09.27_Psy_AgarPads#13_Pos63
# 2023.09.27_Psy_AgarPads#13_Pos41 2023.09.27_Psy_AgarPads#13_Pos69
# 2023.09.27_Psy_AgarPads#13_Pos42 2023.09.27_Psy_AgarPads#13_Pos71
# 2023.09.27_Psy_AgarPads#13_Pos44 2023.09.27_Psy_AgarPads#13_Pos75
# 2023.09.27_Psy_AgarPads#13_Pos47 RawData_from_microscope
# 2023.09.27_Psy_AgarPads#13_Pos49 config_2D.json
# 2023.09.27_Psy_AgarPads#13_Pos50 config_2D_local.json
# 2023.09.27_Psy_AgarPads#13_Pos51 config_mothermachine.json
# 2023.09.27_Psy_AgarPads#13_Pos55 extra_batch_script.ipynb
# 2023.09.27_Psy_AgarPads#13_Pos60 models
# 2023.09.27_Psy_AgarPads#13_Pos62

# %% [markdown]
# ---

# %% [markdown]
# ## Modify Config Files
#
# The Delta Pipeline is controlled using `.json` [config files](https://delta.readthedocs.io/en/latest/usage/config_desc.html). By default two config files are provide: one for 1D mother machine data: `config_mothermachine.json` and one for 2D (microcolony or flowcell) data: `config_2D.json`.
#
# You need to modify these config files to point Delta to the correct data folder.
# We also need to specify the correct path to the pre-trained models.
#
# Here we will open the config file using the [`json`](https://docs.python.org/3/library/json.html) package:

# %%
# select config file to modify ('2D' or 'mothermachine'):
config_filename = strain_dir / 'config_2D.json'
with open(config_filename) as f:
    config = json.load(f)

# %% [markdown]
# Now we have to modify the relevant fields to point to the correct paths.

# %% [markdown]
# *Technical note: reminder: `delta` needs paths specified as strings, we can make a quick function to do this:*

# %%
def to_str(posixpath):
    return str(posixpath.resolve())

# %%
#point to model location
config['model_file_seg'] = to_str(model_dir / 'unet_pads_seg.hdf5')    
config['model_file_track'] = to_str(model_dir / 'unet_pads_track.hdf5')    

#only needed for model training, in that case, point to location of training data
config['training_set_seg'] = ''
config['training_set_track'] = ''

#point to raw data location
config['eval_movie'] = '' #to_str(data_dir)

#specify output formats
config['save_format'] = ["pickle", "movie"]

# %% [markdown]
# Now we can write the config file back to disk:

# %%
new_config_filename = strain_dir / 'config_2D_local.json'
with open(new_config_filename, 'w') as f:
    json.dump(config, f, indent=2)

# %% [markdown]
# ---

# %% [markdown]
# ## Batch process multiple positions for each strain

# %%
folder_names = sorted(strain_dir.glob('*Pos*'))
for folder in folder_names: print(folder.name)
# Out:
# 2023.09.27_Psy_AgarPads#13_Pos41
# 2023.09.27_Psy_AgarPads#13_Pos42
# 2023.09.27_Psy_AgarPads#13_Pos44
# 2023.09.27_Psy_AgarPads#13_Pos47
# 2023.09.27_Psy_AgarPads#13_Pos49
# 2023.09.27_Psy_AgarPads#13_Pos50
# 2023.09.27_Psy_AgarPads#13_Pos51
# 2023.09.27_Psy_AgarPads#13_Pos55
# 2023.09.27_Psy_AgarPads#13_Pos60
# 2023.09.27_Psy_AgarPads#13_Pos62
# 2023.09.27_Psy_AgarPads#13_Pos63
# 2023.09.27_Psy_AgarPads#13_Pos69
# 2023.09.27_Psy_AgarPads#13_Pos71
# 2023.09.27_Psy_AgarPads#13_Pos75

# %%
for folder in folder_names:

    posname = folder.name
    print('running position ', posname)
    
    #path to current position
    data_dir = strain_dir / posname #/ 'RawData'
    
    #make subfolder for current position
    output_dir = strain_dir / posname / 'ProcessedData'
    (output_dir).mkdir(exist_ok=True)  
    
    myprototype = 'C%01i-'+posname+'_crop%04i.tif'
    
    try:            
        # Load config ('2D' or 'mothermachine'):
        delta.config.load_config(new_config_filename)

        # Init reader (use bioformats=True if working with nd2, czi, ome-tiff etc):
        xpreader = delta.utils.xpreader(
                    data_dir,
                    prototype = myprototype,
                    fileorder = 'ct',
                    filenamesindexing=1
                    )

        # Print experiment parameters to make sure it initialized properly:
        print("""Initialized experiment reader:
            - %d positions
            - %d imaging channels
            - %d timepoints"""%(xpreader.positions, xpreader.channels, xpreader.timepoints)
        )

        # Init pipeline:
        xp = delta.pipeline.Pipeline(xpreader, resfolder=output_dir)   

        # Run it (you can specify which positions, which frames to run etc):
        xp.process()
        
    except:
        print('skipping postion', posname)
# Out:
# running position  2023.09.27_Psy_AgarPads#13_Pos41
# Loading configuration from: /Users/jluneau/Documents/Image_analysis/Pseudomonas/2023.09.27_Psy_AgarPads#13/Psy-eGFP/config_2D_local.json
# Initialized experiment reader:
#             - 1 positions
#             - 2 imaging channels
#             - 53 timepoints
# Metal device set to: Apple M1 Pro
# Mon Oct 16 23:53:10 2023, Position 0 - Starting pre-processing
# Mon Oct 16 23:53:10 2023, Position 0 - Starting segmentation (53 frames)
# 64/64 [==============================] - 13s 156ms/step
# 64/64 [==============================] - 10s 154ms/step
# 64/64 [==============================] - 10s 155ms/step
# 64/64 [==============================] - 10s 155ms/step
# 62/62 [==============================] - 10s 157ms/step
# Mon Oct 16 23:54:06 2023, Position 0 - Starting tracking (53 frames)
# Mon Oct 16 23:54:06 2023, Position 0 - Tracking - frame 0/53
# Mon Oct 16 23:54:06 2023, Position 0 - Tracking - frame 1/53
# Mon Oct 16 23:54:09 2023, Position 0 - Tracking - frame 2/53
# Mon Oct 16 23:54:10 2023, Position 0 - Tracking - frame 3/53
# Mon Oct 16 23:54:10 2023, Position 0 - Tracking - frame 4/53
# Mon Oct 16 23:54:11 2023, Position 0 - Tracking - frame 5/53
# Mon Oct 16 23:54:11 2023, Position 0 - Tracking - frame 6/53
# Mon Oct 16 23:54:12 2023, Position 0 - Tracking - frame 7/53
# Mon Oct 16 23:54:12 2023, Position 0 - Tracking - frame 8/53
# Mon Oct 16 23:54:13 2023, Position 0 - Tracking - frame 9/53
# Mon Oct 16 23:54:13 2023, Position 0 - Tracking - frame 10/53
# Mon Oct 16 23:54:14 2023, Position 0 - Tracking - frame 11/53
# Mon Oct 16 23:54:15 2023, Position 0 - Tracking - frame 12/53
# Mon Oct 16 23:54:16 2023, Position 0 - Tracking - frame 13/53
# Mon Oct 16 23:54:17 2023, Position 0 - Tracking - frame 14/53
# Mon Oct 16 23:54:18 2023, Position 0 - Tracking - frame 15/53
# Mon Oct 16 23:54:19 2023, Position 0 - Tracking - frame 16/53
# Mon Oct 16 23:54:21 2023, Position 0 - Tracking - frame 17/53
# Mon Oct 16 23:54:22 2023, Position 0 - Tracking - frame 18/53
# Mon Oct 16 23:54:23 2023, Position 0 - Tracking - frame 19/53
# Mon Oct 16 23:54:24 2023, Position 0 - Tracking - frame 20/53
# Mon Oct 16 23:54:26 2023, Position 0 - Tracking - frame 21/53
# Mon Oct 16 23:54:28 2023, Position 0 - Tracking - frame 22/53
# Mon Oct 16 23:54:30 2023, Position 0 - Tracking - frame 23/53
# Mon Oct 16 23:54:32 2023, Position 0 - Tracking - frame 24/53
# Mon Oct 16 23:54:34 2023, Position 0 - Tracking - frame 25/53
# Mon Oct 16 23:54:37 2023, Position 0 - Tracking - frame 26/53
# Mon Oct 16 23:54:40 2023, Position 0 - Tracking - frame 27/53
# Mon Oct 16 23:54:43 2023, Position 0 - Tracking - frame 28/53
# Mon Oct 16 23:54:46 2023, Position 0 - Tracking - frame 29/53
# Mon Oct 16 23:54:50 2023, Position 0 - Tracking - frame 30/53
# Mon Oct 16 23:54:55 2023, Position 0 - Tracking - frame 31/53
# Mon Oct 16 23:55:00 2023, Position 0 - Tracking - frame 32/53
# Mon Oct 16 23:55:05 2023, Position 0 - Tracking - frame 33/53
# Mon Oct 16 23:55:10 2023, Position 0 - Tracking - frame 34/53
# Mon Oct 16 23:55:15 2023, Position 0 - Tracking - frame 35/53
# Mon Oct 16 23:55:21 2023, Position 0 - Tracking - frame 36/53
# Mon Oct 16 23:55:27 2023, Position 0 - Tracking - frame 37/53
# Mon Oct 16 23:55:34 2023, Position 0 - Tracking - frame 38/53
# Mon Oct 16 23:55:43 2023, Position 0 - Tracking - frame 39/53
# Mon Oct 16 23:55:52 2023, Position 0 - Tracking - frame 40/53
# Mon Oct 16 23:56:01 2023, Position 0 - Tracking - frame 41/53
# Mon Oct 16 23:56:11 2023, Position 0 - Tracking - frame 42/53
# Mon Oct 16 23:56:20 2023, Position 0 - Tracking - frame 43/53
# Mon Oct 16 23:56:30 2023, Position 0 - Tracking - frame 44/53
# Mon Oct 16 23:56:41 2023, Position 0 - Tracking - frame 45/53
# Mon Oct 16 23:56:53 2023, Position 0 - Tracking - frame 46/53
# Mon Oct 16 23:57:07 2023, Position 0 - Tracking - frame 47/53
# Mon Oct 16 23:57:23 2023, Position 0 - Tracking - frame 48/53
# Mon Oct 16 23:57:39 2023, Position 0 - Tracking - frame 49/53
# Mon Oct 16 23:57:56 2023, Position 0 - Tracking - frame 50/53
# Mon Oct 16 23:58:14 2023, Position 0 - Tracking - frame 51/53
# Mon Oct 16 23:58:32 2023, Position 0 - Tracking - frame 52/53
# Mon Oct 16 23:58:50 2023, Position 0 - Starting feature extraction (53 frames)
# Mon Oct 16 23:58:50 2023, Position 0 - Feature extraction - frame 0/53
# Mon Oct 16 23:58:50 2023, Position 0 - Feature extraction - frame 1/53
# Mon Oct 16 23:58:50 2023, Position 0 - Feature extraction - frame 2/53
# Mon Oct 16 23:58:51 2023, Position 0 - Feature extraction - frame 3/53
# Mon Oct 16 23:58:51 2023, Position 0 - Feature extraction - frame 4/53
# Mon Oct 16 23:58:51 2023, Position 0 - Feature extraction - frame 5/53
# Mon Oct 16 23:58:51 2023, Position 0 - Feature extraction - frame 6/53
# Mon Oct 16 23:58:51 2023, Position 0 - Feature extraction - frame 7/53
# Mon Oct 16 23:58:51 2023, Position 0 - Feature extraction - frame 8/53
# Mon Oct 16 23:58:51 2023, Position 0 - Feature extraction - frame 9/53
# Mon Oct 16 23:58:51 2023, Position 0 - Feature extraction - frame 10/53
# Mon Oct 16 23:58:51 2023, Position 0 - Feature extraction - frame 11/53
# Mon Oct 16 23:58:51 2023, Position 0 - Feature extraction - frame 12/53
# Mon Oct 16 23:58:51 2023, Position 0 - Feature extraction - frame 13/53
# Mon Oct 16 23:58:51 2023, Position 0 - Feature extraction - frame 14/53
# Mon Oct 16 23:58:51 2023, Position 0 - Feature extraction - frame 15/53
# Mon Oct 16 23:58:51 2023, Position 0 - Feature extraction - frame 16/53
# Mon Oct 16 23:58:51 2023, Position 0 - Feature extraction - frame 17/53
# Mon Oct 16 23:58:51 2023, Position 0 - Feature extraction - frame 18/53
# Mon Oct 16 23:58:51 2023, Position 0 - Feature extraction - frame 19/53
# Mon Oct 16 23:58:51 2023, Position 0 - Feature extraction - frame 20/53
# Mon Oct 16 23:58:51 2023, Position 0 - Feature extraction - frame 21/53
# Mon Oct 16 23:58:51 2023, Position 0 - Feature extraction - frame 22/53
# Mon Oct 16 23:58:52 2023, Position 0 - Feature extraction - frame 23/53
# Mon Oct 16 23:58:52 2023, Position 0 - Feature extraction - frame 24/53
# Mon Oct 16 23:58:52 2023, Position 0 - Feature extraction - frame 25/53
# Mon Oct 16 23:58:52 2023, Position 0 - Feature extraction - frame 26/53
# Mon Oct 16 23:58:52 2023, Position 0 - Feature extraction - frame 27/53
# Mon Oct 16 23:58:52 2023, Position 0 - Feature extraction - frame 28/53
# Mon Oct 16 23:58:52 2023, Position 0 - Feature extraction - frame 29/53
# Mon Oct 16 23:58:53 2023, Position 0 - Feature extraction - frame 30/53
# Mon Oct 16 23:58:53 2023, Position 0 - Feature extraction - frame 31/53
# Mon Oct 16 23:58:53 2023, Position 0 - Feature extraction - frame 32/53
# Mon Oct 16 23:58:53 2023, Position 0 - Feature extraction - frame 33/53
# Mon Oct 16 23:58:53 2023, Position 0 - Feature extraction - frame 34/53
# Mon Oct 16 23:58:54 2023, Position 0 - Feature extraction - frame 35/53
# Mon Oct 16 23:58:54 2023, Position 0 - Feature extraction - frame 36/53
# Mon Oct 16 23:58:54 2023, Position 0 - Feature extraction - frame 37/53
# Mon Oct 16 23:58:55 2023, Position 0 - Feature extraction - frame 38/53
# Mon Oct 16 23:58:55 2023, Position 0 - Feature extraction - frame 39/53
# Mon Oct 16 23:58:55 2023, Position 0 - Feature extraction - frame 40/53
# Mon Oct 16 23:58:56 2023, Position 0 - Feature extraction - frame 41/53
# Mon Oct 16 23:58:56 2023, Position 0 - Feature extraction - frame 42/53
# Mon Oct 16 23:58:57 2023, Position 0 - Feature extraction - frame 43/53
# Mon Oct 16 23:58:57 2023, Position 0 - Feature extraction - frame 44/53
# Mon Oct 16 23:58:58 2023, Position 0 - Feature extraction - frame 45/53
# Mon Oct 16 23:58:58 2023, Position 0 - Feature extraction - frame 46/53
# Mon Oct 16 23:58:59 2023, Position 0 - Feature extraction - frame 47/53
# Mon Oct 16 23:59:00 2023, Position 0 - Feature extraction - frame 48/53
# Mon Oct 16 23:59:00 2023, Position 0 - Feature extraction - frame 49/53
# Mon Oct 16 23:59:01 2023, Position 0 - Feature extraction - frame 50/53
# Mon Oct 16 23:59:02 2023, Position 0 - Feature extraction - frame 51/53
# Mon Oct 16 23:59:02 2023, Position 0 - Feature extraction - frame 52/53
# Mon Oct 16 23:59:03 2023, Position 0 - Saving to pickle format
# /Users/jluneau/Documents/Image_analysis/Pseudomonas/2023.09.27_Psy_AgarPads#13/Psy-eGFP/2023.09.27_Psy_AgarPads#13_Pos41/ProcessedData/Position000000.pkl
# Mon Oct 16 23:59:04 2023, Position 0 - Saving results movie
# /Users/jluneau/Documents/Image_analysis/Pseudomonas/2023.09.27_Psy_AgarPads#13/Psy-eGFP/2023.09.27_Psy_AgarPads#13_Pos41/ProcessedData/Position000000.mp4
# Mon Oct 16 23:59:17 2023, Position 0 - Clearing variables from memory
# running position  2023.09.27_Psy_AgarPads#13_Pos42
# Loading configuration from: /Users/jluneau/Documents/Image_analysis/Pseudomonas/2023.09.27_Psy_AgarPads#13/Psy-eGFP/config_2D_local.json
# Initialized experiment reader:
#             - 1 positions
#             - 2 imaging channels
#             - 60 timepoints
# Mon Oct 16 23:59:18 2023, Position 0 - Starting pre-processing
# Mon Oct 16 23:59:18 2023, Position 0 - Starting segmentation (60 frames)
# 64/64 [==============================] - 12s 147ms/step
# 64/64 [==============================] - 9s 147ms/step
# 64/64 [==============================] - 10s 151ms/step
# 48/48 [==============================] - 7s 146ms/step
# Mon Oct 16 23:59:57 2023, Position 0 - Starting tracking (60 frames)
# Mon Oct 16 23:59:57 2023, Position 0 - Tracking - frame 0/60
# Mon Oct 16 23:59:57 2023, Position 0 - Tracking - frame 1/60
# Tue Oct 17 00:00:00 2023, Position 0 - Tracking - frame 2/60
# Tue Oct 17 00:00:00 2023, Position 0 - Tracking - frame 3/60
# Tue Oct 17 00:00:00 2023, Position 0 - Tracking - frame 4/60
# Tue Oct 17 00:00:01 2023, Position 0 - Tracking - frame 5/60
# Tue Oct 17 00:00:01 2023, Position 0 - Tracking - frame 6/60
# Tue Oct 17 00:00:01 2023, Position 0 - Tracking - frame 7/60
# Tue Oct 17 00:00:01 2023, Position 0 - Tracking - frame 8/60
# Tue Oct 17 00:00:02 2023, Position 0 - Tracking - frame 9/60
# Tue Oct 17 00:00:02 2023, Position 0 - Tracking - frame 10/60
# Tue Oct 17 00:00:02 2023, Position 0 - Tracking - frame 11/60
# Tue Oct 17 00:00:03 2023, Position 0 - Tracking - frame 12/60
# Tue Oct 17 00:00:03 2023, Position 0 - Tracking - frame 13/60
# Tue Oct 17 00:00:03 2023, Position 0 - Tracking - frame 14/60
# Tue Oct 17 00:00:04 2023, Position 0 - Tracking - frame 15/60
# Tue Oct 17 00:00:04 2023, Position 0 - Tracking - frame 16/60
# Tue Oct 17 00:00:05 2023, Position 0 - Tracking - frame 17/60
# Tue Oct 17 00:00:05 2023, Position 0 - Tracking - frame 18/60
# Tue Oct 17 00:00:06 2023, Position 0 - Tracking - frame 19/60
# Tue Oct 17 00:00:07 2023, Position 0 - Tracking - frame 20/60
# Tue Oct 17 00:00:07 2023, Position 0 - Tracking - frame 21/60
# Tue Oct 17 00:00:08 2023, Position 0 - Tracking - frame 22/60
# Tue Oct 17 00:00:08 2023, Position 0 - Tracking - frame 23/60
# Tue Oct 17 00:00:09 2023, Position 0 - Tracking - frame 24/60
# Tue Oct 17 00:00:10 2023, Position 0 - Tracking - frame 25/60
# Tue Oct 17 00:00:12 2023, Position 0 - Tracking - frame 26/60
# Tue Oct 17 00:00:13 2023, Position 0 - Tracking - frame 27/60
# Tue Oct 17 00:00:14 2023, Position 0 - Tracking - frame 28/60
# Tue Oct 17 00:00:15 2023, Position 0 - Tracking - frame 29/60
# Tue Oct 17 00:00:16 2023, Position 0 - Tracking - frame 30/60
# Tue Oct 17 00:00:17 2023, Position 0 - Tracking - frame 31/60
# Tue Oct 17 00:00:19 2023, Position 0 - Tracking - frame 32/60
# Tue Oct 17 00:00:21 2023, Position 0 - Tracking - frame 33/60
# Tue Oct 17 00:00:23 2023, Position 0 - Tracking - frame 34/60
# Tue Oct 17 00:00:25 2023, Position 0 - Tracking - frame 35/60
# Tue Oct 17 00:00:27 2023, Position 0 - Tracking - frame 36/60
# Tue Oct 17 00:00:30 2023, Position 0 - Tracking - frame 37/60
# Tue Oct 17 00:00:32 2023, Position 0 - Tracking - frame 38/60
# Tue Oct 17 00:00:34 2023, Position 0 - Tracking - frame 39/60
# Tue Oct 17 00:00:37 2023, Position 0 - Tracking - frame 40/60
# Tue Oct 17 00:00:41 2023, Position 0 - Tracking - frame 41/60
# Tue Oct 17 00:00:44 2023, Position 0 - Tracking - frame 42/60
# Tue Oct 17 00:00:48 2023, Position 0 - Tracking - frame 43/60
# Tue Oct 17 00:00:53 2023, Position 0 - Tracking - frame 44/60
# Tue Oct 17 00:00:57 2023, Position 0 - Tracking - frame 45/60
# Tue Oct 17 00:01:01 2023, Position 0 - Tracking - frame 46/60
# Tue Oct 17 00:01:06 2023, Position 0 - Tracking - frame 47/60
# Tue Oct 17 00:01:10 2023, Position 0 - Tracking - frame 48/60
# Tue Oct 17 00:01:15 2023, Position 0 - Tracking - frame 49/60
# Tue Oct 17 00:01:20 2023, Position 0 - Tracking - frame 50/60
# Tue Oct 17 00:01:25 2023, Position 0 - Tracking - frame 51/60
# Tue Oct 17 00:01:31 2023, Position 0 - Tracking - frame 52/60
# Tue Oct 17 00:01:37 2023, Position 0 - Tracking - frame 53/60
# Tue Oct 17 00:01:43 2023, Position 0 - Tracking - frame 54/60
# Tue Oct 17 00:01:51 2023, Position 0 - Tracking - frame 55/60
# Tue Oct 17 00:01:59 2023, Position 0 - Tracking - frame 56/60
# Tue Oct 17 00:02:07 2023, Position 0 - Tracking - frame 57/60
# Tue Oct 17 00:02:16 2023, Position 0 - Tracking - frame 58/60
# Tue Oct 17 00:02:24 2023, Position 0 - Tracking - frame 59/60
# Tue Oct 17 00:02:33 2023, Position 0 - Starting feature extraction (60 frames)
# Tue Oct 17 00:02:33 2023, Position 0 - Feature extraction - frame 0/60
# Tue Oct 17 00:02:33 2023, Position 0 - Feature extraction - frame 1/60
# Tue Oct 17 00:02:33 2023, Position 0 - Feature extraction - frame 2/60
# Tue Oct 17 00:02:33 2023, Position 0 - Feature extraction - frame 3/60
# Tue Oct 17 00:02:33 2023, Position 0 - Feature extraction - frame 4/60
# Tue Oct 17 00:02:33 2023, Position 0 - Feature extraction - frame 5/60
# Tue Oct 17 00:02:33 2023, Position 0 - Feature extraction - frame 6/60
# Tue Oct 17 00:02:33 2023, Position 0 - Feature extraction - frame 7/60
# Tue Oct 17 00:02:33 2023, Position 0 - Feature extraction - frame 8/60
# Tue Oct 17 00:02:33 2023, Position 0 - Feature extraction - frame 9/60
# Tue Oct 17 00:02:33 2023, Position 0 - Feature extraction - frame 10/60
# Tue Oct 17 00:02:33 2023, Position 0 - Feature extraction - frame 11/60
# Tue Oct 17 00:02:33 2023, Position 0 - Feature extraction - frame 12/60
# Tue Oct 17 00:02:33 2023, Position 0 - Feature extraction - frame 13/60
# Tue Oct 17 00:02:33 2023, Position 0 - Feature extraction - frame 14/60
# Tue Oct 17 00:02:33 2023, Position 0 - Feature extraction - frame 15/60
# Tue Oct 17 00:02:33 2023, Position 0 - Feature extraction - frame 16/60
# Tue Oct 17 00:02:33 2023, Position 0 - Feature extraction - frame 17/60
# Tue Oct 17 00:02:33 2023, Position 0 - Feature extraction - frame 18/60
# Tue Oct 17 00:02:33 2023, Position 0 - Feature extraction - frame 19/60
# Tue Oct 17 00:02:33 2023, Position 0 - Feature extraction - frame 20/60
# Tue Oct 17 00:02:33 2023, Position 0 - Feature extraction - frame 21/60
# Tue Oct 17 00:02:33 2023, Position 0 - Feature extraction - frame 22/60
# Tue Oct 17 00:02:33 2023, Position 0 - Feature extraction - frame 23/60
# Tue Oct 17 00:02:33 2023, Position 0 - Feature extraction - frame 24/60
# Tue Oct 17 00:02:34 2023, Position 0 - Feature extraction - frame 25/60
# Tue Oct 17 00:02:34 2023, Position 0 - Feature extraction - frame 26/60
# Tue Oct 17 00:02:34 2023, Position 0 - Feature extraction - frame 27/60
# Tue Oct 17 00:02:34 2023, Position 0 - Feature extraction - frame 28/60
# Tue Oct 17 00:02:34 2023, Position 0 - Feature extraction - frame 29/60
# Tue Oct 17 00:02:34 2023, Position 0 - Feature extraction - frame 30/60
# Tue Oct 17 00:02:34 2023, Position 0 - Feature extraction - frame 31/60
# Tue Oct 17 00:02:34 2023, Position 0 - Feature extraction - frame 32/60
# Tue Oct 17 00:02:34 2023, Position 0 - Feature extraction - frame 33/60
# Tue Oct 17 00:02:34 2023, Position 0 - Feature extraction - frame 34/60
# Tue Oct 17 00:02:34 2023, Position 0 - Feature extraction - frame 35/60
# Tue Oct 17 00:02:34 2023, Position 0 - Feature extraction - frame 36/60
# Tue Oct 17 00:02:34 2023, Position 0 - Feature extraction - frame 37/60
# Tue Oct 17 00:02:34 2023, Position 0 - Feature extraction - frame 38/60
# Tue Oct 17 00:02:34 2023, Position 0 - Feature extraction - frame 39/60
# Tue Oct 17 00:02:34 2023, Position 0 - Feature extraction - frame 40/60
# Tue Oct 17 00:02:34 2023, Position 0 - Feature extraction - frame 41/60
# Tue Oct 17 00:02:34 2023, Position 0 - Feature extraction - frame 42/60
# Tue Oct 17 00:02:34 2023, Position 0 - Feature extraction - frame 43/60
# Tue Oct 17 00:02:34 2023, Position 0 - Feature extraction - frame 44/60
# Tue Oct 17 00:02:34 2023, Position 0 - Feature extraction - frame 45/60
# Tue Oct 17 00:02:35 2023, Position 0 - Feature extraction - frame 46/60
# Tue Oct 17 00:02:35 2023, Position 0 - Feature extraction - frame 47/60
# Tue Oct 17 00:02:35 2023, Position 0 - Feature extraction - frame 48/60
# Tue Oct 17 00:02:35 2023, Position 0 - Feature extraction - frame 49/60
# Tue Oct 17 00:02:35 2023, Position 0 - Feature extraction - frame 50/60
# Tue Oct 17 00:02:35 2023, Position 0 - Feature extraction - frame 51/60
# Tue Oct 17 00:02:35 2023, Position 0 - Feature extraction - frame 52/60
# Tue Oct 17 00:02:35 2023, Position 0 - Feature extraction - frame 53/60
# Tue Oct 17 00:02:35 2023, Position 0 - Feature extraction - frame 54/60
# Tue Oct 17 00:02:36 2023, Position 0 - Feature extraction - frame 55/60
# Tue Oct 17 00:02:36 2023, Position 0 - Feature extraction - frame 56/60
# Tue Oct 17 00:02:36 2023, Position 0 - Feature extraction - frame 57/60
# Tue Oct 17 00:02:36 2023, Position 0 - Feature extraction - frame 58/60
# Tue Oct 17 00:02:36 2023, Position 0 - Feature extraction - frame 59/60
# Tue Oct 17 00:02:36 2023, Position 0 - Saving to pickle format
# /Users/jluneau/Documents/Image_analysis/Pseudomonas/2023.09.27_Psy_AgarPads#13/Psy-eGFP/2023.09.27_Psy_AgarPads#13_Pos42/ProcessedData/Position000000.pkl
# Tue Oct 17 00:02:37 2023, Position 0 - Saving results movie
# /Users/jluneau/Documents/Image_analysis/Pseudomonas/2023.09.27_Psy_AgarPads#13/Psy-eGFP/2023.09.27_Psy_AgarPads#13_Pos42/ProcessedData/Position000000.mp4
# Tue Oct 17 00:02:43 2023, Position 0 - Clearing variables from memory
# running position  2023.09.27_Psy_AgarPads#13_Pos44
# Loading configuration from: /Users/jluneau/Documents/Image_analysis/Pseudomonas/2023.09.27_Psy_AgarPads#13/Psy-eGFP/config_2D_local.json
# Initialized experiment reader:
#             - 1 positions
#             - 2 imaging channels
#             - 60 timepoints
# Tue Oct 17 00:02:43 2023, Position 0 - Starting pre-processing
# Tue Oct 17 00:02:43 2023, Position 0 - Starting segmentation (60 frames)
# 64/64 [==============================] - 12s 147ms/step
# 64/64 [==============================] - 9s 146ms/step
# 64/64 [==============================] - 10s 149ms/step
# 64/64 [==============================] - 9s 148ms/step
# 64/64 [==============================] - 9s 147ms/step
# 64/64 [==============================] - 9s 147ms/step
# 64/64 [==============================] - 9s 147ms/step
# 64/64 [==============================] - 9s 147ms/step
# 28/28 [==============================] - 4s 147ms/step
# Tue Oct 17 00:04:10 2023, Position 0 - Starting tracking (60 frames)
# Tue Oct 17 00:04:10 2023, Position 0 - Tracking - frame 0/60
# Tue Oct 17 00:04:10 2023, Position 0 - Tracking - frame 1/60
# Tue Oct 17 00:04:13 2023, Position 0 - Tracking - frame 2/60
# Tue Oct 17 00:04:13 2023, Position 0 - Tracking - frame 3/60
# Tue Oct 17 00:04:13 2023, Position 0 - Tracking - frame 4/60
# Tue Oct 17 00:04:14 2023, Position 0 - Tracking - frame 5/60
# Tue Oct 17 00:04:14 2023, Position 0 - Tracking - frame 6/60
# Tue Oct 17 00:04:15 2023, Position 0 - Tracking - frame 7/60
# Tue Oct 17 00:04:15 2023, Position 0 - Tracking - frame 8/60
# Tue Oct 17 00:04:16 2023, Position 0 - Tracking - frame 9/60
# Tue Oct 17 00:04:16 2023, Position 0 - Tracking - frame 10/60
# Tue Oct 17 00:04:17 2023, Position 0 - Tracking - frame 11/60
# Tue Oct 17 00:04:18 2023, Position 0 - Tracking - frame 12/60
# Tue Oct 17 00:04:19 2023, Position 0 - Tracking - frame 13/60
# Tue Oct 17 00:04:20 2023, Position 0 - Tracking - frame 14/60
# Tue Oct 17 00:04:20 2023, Position 0 - Tracking - frame 15/60
# Tue Oct 17 00:04:21 2023, Position 0 - Tracking - frame 16/60
# Tue Oct 17 00:04:22 2023, Position 0 - Tracking - frame 17/60
# Tue Oct 17 00:04:24 2023, Position 0 - Tracking - frame 18/60
# Tue Oct 17 00:04:25 2023, Position 0 - Tracking - frame 19/60
# Tue Oct 17 00:04:27 2023, Position 0 - Tracking - frame 20/60
# Tue Oct 17 00:04:28 2023, Position 0 - Tracking - frame 21/60
# Tue Oct 17 00:04:30 2023, Position 0 - Tracking - frame 22/60
# Tue Oct 17 00:04:32 2023, Position 0 - Tracking - frame 23/60
# Tue Oct 17 00:04:34 2023, Position 0 - Tracking - frame 24/60
# Tue Oct 17 00:04:37 2023, Position 0 - Tracking - frame 25/60
# Tue Oct 17 00:04:39 2023, Position 0 - Tracking - frame 26/60
# Tue Oct 17 00:04:42 2023, Position 0 - Tracking - frame 27/60
# Tue Oct 17 00:04:45 2023, Position 0 - Tracking - frame 28/60
# Tue Oct 17 00:04:49 2023, Position 0 - Tracking - frame 29/60
# Tue Oct 17 00:04:52 2023, Position 0 - Tracking - frame 30/60
# Tue Oct 17 00:04:56 2023, Position 0 - Tracking - frame 31/60
# Tue Oct 17 00:05:00 2023, Position 0 - Tracking - frame 32/60
# Tue Oct 17 00:05:04 2023, Position 0 - Tracking - frame 33/60
# Tue Oct 17 00:05:09 2023, Position 0 - Tracking - frame 34/60
# Tue Oct 17 00:05:15 2023, Position 0 - Tracking - frame 35/60
# Tue Oct 17 00:05:21 2023, Position 0 - Tracking - frame 36/60
# Tue Oct 17 00:05:28 2023, Position 0 - Tracking - frame 37/60
# Tue Oct 17 00:05:35 2023, Position 0 - Tracking - frame 38/60
# Tue Oct 17 00:05:42 2023, Position 0 - Tracking - frame 39/60
# Tue Oct 17 00:05:50 2023, Position 0 - Tracking - frame 40/60
# Tue Oct 17 00:05:58 2023, Position 0 - Tracking - frame 41/60
# Tue Oct 17 00:06:07 2023, Position 0 - Tracking - frame 42/60
# Tue Oct 17 00:06:17 2023, Position 0 - Tracking - frame 43/60
# Tue Oct 17 00:06:27 2023, Position 0 - Tracking - frame 44/60
# Tue Oct 17 00:06:39 2023, Position 0 - Tracking - frame 45/60
# Tue Oct 17 00:06:50 2023, Position 0 - Tracking - frame 46/60
# Tue Oct 17 00:07:03 2023, Position 0 - Tracking - frame 47/60
# Tue Oct 17 00:07:16 2023, Position 0 - Tracking - frame 48/60
# Tue Oct 17 00:07:30 2023, Position 0 - Tracking - frame 49/60
# Tue Oct 17 00:07:45 2023, Position 0 - Tracking - frame 50/60
# Tue Oct 17 00:08:00 2023, Position 0 - Tracking - frame 51/60
# Tue Oct 17 00:08:16 2023, Position 0 - Tracking - frame 52/60
# Tue Oct 17 00:08:33 2023, Position 0 - Tracking - frame 53/60
# Tue Oct 17 00:08:50 2023, Position 0 - Tracking - frame 54/60
# Tue Oct 17 00:09:07 2023, Position 0 - Tracking - frame 55/60
# Tue Oct 17 00:09:27 2023, Position 0 - Tracking - frame 56/60
# Tue Oct 17 00:09:46 2023, Position 0 - Tracking - frame 57/60
# Tue Oct 17 00:10:07 2023, Position 0 - Tracking - frame 58/60
# Tue Oct 17 00:10:30 2023, Position 0 - Tracking - frame 59/60
# Tue Oct 17 00:10:53 2023, Position 0 - Starting feature extraction (60 frames)
# Tue Oct 17 00:10:54 2023, Position 0 - Feature extraction - frame 0/60
# Tue Oct 17 00:10:54 2023, Position 0 - Feature extraction - frame 1/60
# Tue Oct 17 00:10:54 2023, Position 0 - Feature extraction - frame 2/60
# Tue Oct 17 00:10:54 2023, Position 0 - Feature extraction - frame 3/60
# Tue Oct 17 00:10:54 2023, Position 0 - Feature extraction - frame 4/60
# Tue Oct 17 00:10:54 2023, Position 0 - Feature extraction - frame 5/60
# Tue Oct 17 00:10:54 2023, Position 0 - Feature extraction - frame 6/60
# Tue Oct 17 00:10:54 2023, Position 0 - Feature extraction - frame 7/60
# Tue Oct 17 00:10:54 2023, Position 0 - Feature extraction - frame 8/60
# Tue Oct 17 00:10:54 2023, Position 0 - Feature extraction - frame 9/60
# Tue Oct 17 00:10:54 2023, Position 0 - Feature extraction - frame 10/60
# Tue Oct 17 00:10:54 2023, Position 0 - Feature extraction - frame 11/60
# Tue Oct 17 00:10:54 2023, Position 0 - Feature extraction - frame 12/60
# Tue Oct 17 00:10:54 2023, Position 0 - Feature extraction - frame 13/60
# Tue Oct 17 00:10:54 2023, Position 0 - Feature extraction - frame 14/60
# Tue Oct 17 00:10:54 2023, Position 0 - Feature extraction - frame 15/60
# Tue Oct 17 00:10:55 2023, Position 0 - Feature extraction - frame 16/60
# Tue Oct 17 00:10:55 2023, Position 0 - Feature extraction - frame 17/60
# Tue Oct 17 00:10:55 2023, Position 0 - Feature extraction - frame 18/60
# Tue Oct 17 00:10:55 2023, Position 0 - Feature extraction - frame 19/60
# Tue Oct 17 00:10:55 2023, Position 0 - Feature extraction - frame 20/60
# Tue Oct 17 00:10:55 2023, Position 0 - Feature extraction - frame 21/60
# Tue Oct 17 00:10:55 2023, Position 0 - Feature extraction - frame 22/60
# Tue Oct 17 00:10:55 2023, Position 0 - Feature extraction - frame 23/60
# Tue Oct 17 00:10:55 2023, Position 0 - Feature extraction - frame 24/60
# Tue Oct 17 00:10:56 2023, Position 0 - Feature extraction - frame 25/60
# Tue Oct 17 00:10:56 2023, Position 0 - Feature extraction - frame 26/60
# Tue Oct 17 00:10:56 2023, Position 0 - Feature extraction - frame 27/60
# Tue Oct 17 00:10:56 2023, Position 0 - Feature extraction - frame 28/60
# Tue Oct 17 00:10:56 2023, Position 0 - Feature extraction - frame 29/60
# Tue Oct 17 00:10:56 2023, Position 0 - Feature extraction - frame 30/60
# Tue Oct 17 00:10:57 2023, Position 0 - Feature extraction - frame 31/60
# Tue Oct 17 00:10:57 2023, Position 0 - Feature extraction - frame 32/60
# Tue Oct 17 00:10:57 2023, Position 0 - Feature extraction - frame 33/60
# Tue Oct 17 00:10:58 2023, Position 0 - Feature extraction - frame 34/60
# Tue Oct 17 00:10:58 2023, Position 0 - Feature extraction - frame 35/60
# Tue Oct 17 00:10:58 2023, Position 0 - Feature extraction - frame 36/60
# Tue Oct 17 00:10:59 2023, Position 0 - Feature extraction - frame 37/60
# Tue Oct 17 00:10:59 2023, Position 0 - Feature extraction - frame 38/60
# Tue Oct 17 00:11:00 2023, Position 0 - Feature extraction - frame 39/60
# Tue Oct 17 00:11:00 2023, Position 0 - Feature extraction - frame 40/60
# Tue Oct 17 00:11:00 2023, Position 0 - Feature extraction - frame 41/60
# Tue Oct 17 00:11:01 2023, Position 0 - Feature extraction - frame 42/60
# Tue Oct 17 00:11:02 2023, Position 0 - Feature extraction - frame 43/60
# Tue Oct 17 00:11:02 2023, Position 0 - Feature extraction - frame 44/60
# Tue Oct 17 00:11:03 2023, Position 0 - Feature extraction - frame 45/60
# Tue Oct 17 00:11:04 2023, Position 0 - Feature extraction - frame 46/60
# Tue Oct 17 00:11:04 2023, Position 0 - Feature extraction - frame 47/60
# Tue Oct 17 00:11:05 2023, Position 0 - Feature extraction - frame 48/60
# Tue Oct 17 00:11:06 2023, Position 0 - Feature extraction - frame 49/60
# Tue Oct 17 00:11:07 2023, Position 0 - Feature extraction - frame 50/60
# Tue Oct 17 00:11:08 2023, Position 0 - Feature extraction - frame 51/60
# Tue Oct 17 00:11:08 2023, Position 0 - Feature extraction - frame 52/60
# Tue Oct 17 00:11:09 2023, Position 0 - Feature extraction - frame 53/60
# Tue Oct 17 00:11:10 2023, Position 0 - Feature extraction - frame 54/60
# Tue Oct 17 00:11:11 2023, Position 0 - Feature extraction - frame 55/60
# Tue Oct 17 00:11:12 2023, Position 0 - Feature extraction - frame 56/60
# Tue Oct 17 00:11:14 2023, Position 0 - Feature extraction - frame 57/60
# Tue Oct 17 00:11:15 2023, Position 0 - Feature extraction - frame 58/60
# Tue Oct 17 00:11:16 2023, Position 0 - Feature extraction - frame 59/60
# Tue Oct 17 00:11:17 2023, Position 0 - Saving to pickle format
# /Users/jluneau/Documents/Image_analysis/Pseudomonas/2023.09.27_Psy_AgarPads#13/Psy-eGFP/2023.09.27_Psy_AgarPads#13_Pos44/ProcessedData/Position000000.pkl
# Tue Oct 17 00:11:18 2023, Position 0 - Saving results movie
# /Users/jluneau/Documents/Image_analysis/Pseudomonas/2023.09.27_Psy_AgarPads#13/Psy-eGFP/2023.09.27_Psy_AgarPads#13_Pos44/ProcessedData/Position000000.mp4
# Tue Oct 17 00:11:36 2023, Position 0 - Clearing variables from memory
# running position  2023.09.27_Psy_AgarPads#13_Pos47
# Loading configuration from: /Users/jluneau/Documents/Image_analysis/Pseudomonas/2023.09.27_Psy_AgarPads#13/Psy-eGFP/config_2D_local.json
# Initialized experiment reader:
#             - 1 positions
#             - 2 imaging channels
#             - 60 timepoints
# Tue Oct 17 00:11:37 2023, Position 0 - Starting pre-processing
# Tue Oct 17 00:11:37 2023, Position 0 - Starting segmentation (60 frames)
# 64/64 [==============================] - 12s 148ms/step
# 64/64 [==============================] - 9s 148ms/step
# 64/64 [==============================] - 9s 146ms/step
# 64/64 [==============================] - 9s 147ms/step
# 64/64 [==============================] - 9s 146ms/step
# 64/64 [==============================] - 9s 147ms/step
# 64/64 [==============================] - 9s 147ms/step
# 64/64 [==============================] - 9s 147ms/step
# 28/28 [==============================] - 4s 147ms/step
# Tue Oct 17 00:13:04 2023, Position 0 - Starting tracking (60 frames)
# Tue Oct 17 00:13:04 2023, Position 0 - Tracking - frame 0/60
# Tue Oct 17 00:13:04 2023, Position 0 - Tracking - frame 1/60
# Tue Oct 17 00:13:07 2023, Position 0 - Tracking - frame 2/60
# Tue Oct 17 00:13:08 2023, Position 0 - Tracking - frame 3/60
# Tue Oct 17 00:13:08 2023, Position 0 - Tracking - frame 4/60
# Tue Oct 17 00:13:09 2023, Position 0 - Tracking - frame 5/60
# Tue Oct 17 00:13:09 2023, Position 0 - Tracking - frame 6/60
# Tue Oct 17 00:13:09 2023, Position 0 - Tracking - frame 7/60
# Tue Oct 17 00:13:10 2023, Position 0 - Tracking - frame 8/60
# Tue Oct 17 00:13:10 2023, Position 0 - Tracking - frame 9/60
# Tue Oct 17 00:13:11 2023, Position 0 - Tracking - frame 10/60
# Tue Oct 17 00:13:12 2023, Position 0 - Tracking - frame 11/60
# Tue Oct 17 00:13:13 2023, Position 0 - Tracking - frame 12/60
# Tue Oct 17 00:13:14 2023, Position 0 - Tracking - frame 13/60
# Tue Oct 17 00:13:14 2023, Position 0 - Tracking - frame 14/60
# Tue Oct 17 00:13:16 2023, Position 0 - Tracking - frame 15/60
# Tue Oct 17 00:13:17 2023, Position 0 - Tracking - frame 16/60
# Tue Oct 17 00:13:18 2023, Position 0 - Tracking - frame 17/60
# Tue Oct 17 00:13:19 2023, Position 0 - Tracking - frame 18/60
# Tue Oct 17 00:13:21 2023, Position 0 - Tracking - frame 19/60
# Tue Oct 17 00:13:23 2023, Position 0 - Tracking - frame 20/60
# Tue Oct 17 00:13:24 2023, Position 0 - Tracking - frame 21/60
# Tue Oct 17 00:13:26 2023, Position 0 - Tracking - frame 22/60
# Tue Oct 17 00:13:28 2023, Position 0 - Tracking - frame 23/60
# Tue Oct 17 00:13:30 2023, Position 0 - Tracking - frame 24/60
# Tue Oct 17 00:13:33 2023, Position 0 - Tracking - frame 25/60
# Tue Oct 17 00:13:36 2023, Position 0 - Tracking - frame 26/60
# Tue Oct 17 00:13:39 2023, Position 0 - Tracking - frame 27/60
# Tue Oct 17 00:13:43 2023, Position 0 - Tracking - frame 28/60
# Tue Oct 17 00:13:46 2023, Position 0 - Tracking - frame 29/60
# Tue Oct 17 00:13:50 2023, Position 0 - Tracking - frame 30/60
# Tue Oct 17 00:13:54 2023, Position 0 - Tracking - frame 31/60
# Tue Oct 17 00:13:59 2023, Position 0 - Tracking - frame 32/60
# Tue Oct 17 00:14:05 2023, Position 0 - Tracking - frame 33/60
# Tue Oct 17 00:14:10 2023, Position 0 - Tracking - frame 34/60
# Tue Oct 17 00:14:17 2023, Position 0 - Tracking - frame 35/60
# Tue Oct 17 00:14:23 2023, Position 0 - Tracking - frame 36/60
# Tue Oct 17 00:14:30 2023, Position 0 - Tracking - frame 37/60
# Tue Oct 17 00:14:38 2023, Position 0 - Tracking - frame 38/60
# Tue Oct 17 00:14:45 2023, Position 0 - Tracking - frame 39/60
# Tue Oct 17 00:14:53 2023, Position 0 - Tracking - frame 40/60
# Tue Oct 17 00:15:02 2023, Position 0 - Tracking - frame 41/60
# Tue Oct 17 00:15:12 2023, Position 0 - Tracking - frame 42/60
# Tue Oct 17 00:15:23 2023, Position 0 - Tracking - frame 43/60
# Tue Oct 17 00:15:34 2023, Position 0 - Tracking - frame 44/60
# Tue Oct 17 00:15:47 2023, Position 0 - Tracking - frame 45/60
# Tue Oct 17 00:15:59 2023, Position 0 - Tracking - frame 46/60
# Tue Oct 17 00:16:12 2023, Position 0 - Tracking - frame 47/60
# Tue Oct 17 00:16:26 2023, Position 0 - Tracking - frame 48/60
# Tue Oct 17 00:16:41 2023, Position 0 - Tracking - frame 49/60
# Tue Oct 17 00:16:56 2023, Position 0 - Tracking - frame 50/60
# Tue Oct 17 00:17:12 2023, Position 0 - Tracking - frame 51/60
# Tue Oct 17 00:17:28 2023, Position 0 - Tracking - frame 52/60
# Tue Oct 17 00:17:46 2023, Position 0 - Tracking - frame 53/60
# Tue Oct 17 00:18:04 2023, Position 0 - Tracking - frame 54/60
# Tue Oct 17 00:18:23 2023, Position 0 - Tracking - frame 55/60
# Tue Oct 17 00:18:43 2023, Position 0 - Tracking - frame 56/60
# Tue Oct 17 00:19:05 2023, Position 0 - Tracking - frame 57/60
# Tue Oct 17 00:19:28 2023, Position 0 - Tracking - frame 58/60
# Tue Oct 17 00:19:52 2023, Position 0 - Tracking - frame 59/60
# Tue Oct 17 00:20:17 2023, Position 0 - Starting feature extraction (60 frames)
# Tue Oct 17 00:20:17 2023, Position 0 - Feature extraction - frame 0/60
# Tue Oct 17 00:20:17 2023, Position 0 - Feature extraction - frame 1/60
# Tue Oct 17 00:20:17 2023, Position 0 - Feature extraction - frame 2/60
# Tue Oct 17 00:20:17 2023, Position 0 - Feature extraction - frame 3/60
# Tue Oct 17 00:20:17 2023, Position 0 - Feature extraction - frame 4/60
# Tue Oct 17 00:20:17 2023, Position 0 - Feature extraction - frame 5/60
# Tue Oct 17 00:20:17 2023, Position 0 - Feature extraction - frame 6/60
# Tue Oct 17 00:20:17 2023, Position 0 - Feature extraction - frame 7/60
# Tue Oct 17 00:20:17 2023, Position 0 - Feature extraction - frame 8/60
# Tue Oct 17 00:20:18 2023, Position 0 - Feature extraction - frame 9/60
# Tue Oct 17 00:20:18 2023, Position 0 - Feature extraction - frame 10/60
# Tue Oct 17 00:20:18 2023, Position 0 - Feature extraction - frame 11/60
# Tue Oct 17 00:20:18 2023, Position 0 - Feature extraction - frame 12/60
# Tue Oct 17 00:20:18 2023, Position 0 - Feature extraction - frame 13/60
# Tue Oct 17 00:20:18 2023, Position 0 - Feature extraction - frame 14/60
# Tue Oct 17 00:20:18 2023, Position 0 - Feature extraction - frame 15/60
# Tue Oct 17 00:20:18 2023, Position 0 - Feature extraction - frame 16/60
# Tue Oct 17 00:20:18 2023, Position 0 - Feature extraction - frame 17/60
# Tue Oct 17 00:20:18 2023, Position 0 - Feature extraction - frame 18/60
# Tue Oct 17 00:20:18 2023, Position 0 - Feature extraction - frame 19/60
# Tue Oct 17 00:20:18 2023, Position 0 - Feature extraction - frame 20/60
# Tue Oct 17 00:20:19 2023, Position 0 - Feature extraction - frame 21/60
# Tue Oct 17 00:20:19 2023, Position 0 - Feature extraction - frame 22/60
# Tue Oct 17 00:20:19 2023, Position 0 - Feature extraction - frame 23/60
# Tue Oct 17 00:20:19 2023, Position 0 - Feature extraction - frame 24/60
# Tue Oct 17 00:20:19 2023, Position 0 - Feature extraction - frame 25/60
# Tue Oct 17 00:20:19 2023, Position 0 - Feature extraction - frame 26/60
# Tue Oct 17 00:20:20 2023, Position 0 - Feature extraction - frame 27/60
# Tue Oct 17 00:20:20 2023, Position 0 - Feature extraction - frame 28/60
# Tue Oct 17 00:20:20 2023, Position 0 - Feature extraction - frame 29/60
# Tue Oct 17 00:20:20 2023, Position 0 - Feature extraction - frame 30/60
# Tue Oct 17 00:20:21 2023, Position 0 - Feature extraction - frame 31/60
# Tue Oct 17 00:20:21 2023, Position 0 - Feature extraction - frame 32/60
# Tue Oct 17 00:20:21 2023, Position 0 - Feature extraction - frame 33/60
# Tue Oct 17 00:20:22 2023, Position 0 - Feature extraction - frame 34/60
# Tue Oct 17 00:20:22 2023, Position 0 - Feature extraction - frame 35/60
# Tue Oct 17 00:20:23 2023, Position 0 - Feature extraction - frame 36/60
# Tue Oct 17 00:20:23 2023, Position 0 - Feature extraction - frame 37/60
# Tue Oct 17 00:20:23 2023, Position 0 - Feature extraction - frame 38/60
# Tue Oct 17 00:20:24 2023, Position 0 - Feature extraction - frame 39/60
# Tue Oct 17 00:20:24 2023, Position 0 - Feature extraction - frame 40/60
# Tue Oct 17 00:20:25 2023, Position 0 - Feature extraction - frame 41/60
# Tue Oct 17 00:20:26 2023, Position 0 - Feature extraction - frame 42/60
# Tue Oct 17 00:20:26 2023, Position 0 - Feature extraction - frame 43/60
# Tue Oct 17 00:20:27 2023, Position 0 - Feature extraction - frame 44/60
# Tue Oct 17 00:20:28 2023, Position 0 - Feature extraction - frame 45/60
# Tue Oct 17 00:20:28 2023, Position 0 - Feature extraction - frame 46/60
# Tue Oct 17 00:20:29 2023, Position 0 - Feature extraction - frame 47/60
# Tue Oct 17 00:20:30 2023, Position 0 - Feature extraction - frame 48/60
# Tue Oct 17 00:20:31 2023, Position 0 - Feature extraction - frame 49/60
# Tue Oct 17 00:20:32 2023, Position 0 - Feature extraction - frame 50/60
# Tue Oct 17 00:20:33 2023, Position 0 - Feature extraction - frame 51/60
# Tue Oct 17 00:20:34 2023, Position 0 - Feature extraction - frame 52/60
# Tue Oct 17 00:20:35 2023, Position 0 - Feature extraction - frame 53/60
# Tue Oct 17 00:20:36 2023, Position 0 - Feature extraction - frame 54/60
# Tue Oct 17 00:20:37 2023, Position 0 - Feature extraction - frame 55/60
# Tue Oct 17 00:20:38 2023, Position 0 - Feature extraction - frame 56/60
# Tue Oct 17 00:20:40 2023, Position 0 - Feature extraction - frame 57/60
# Tue Oct 17 00:20:41 2023, Position 0 - Feature extraction - frame 58/60
# Tue Oct 17 00:20:42 2023, Position 0 - Feature extraction - frame 59/60
# Tue Oct 17 00:20:44 2023, Position 0 - Saving to pickle format
# /Users/jluneau/Documents/Image_analysis/Pseudomonas/2023.09.27_Psy_AgarPads#13/Psy-eGFP/2023.09.27_Psy_AgarPads#13_Pos47/ProcessedData/Position000000.pkl
# Tue Oct 17 00:20:45 2023, Position 0 - Saving results movie
# /Users/jluneau/Documents/Image_analysis/Pseudomonas/2023.09.27_Psy_AgarPads#13/Psy-eGFP/2023.09.27_Psy_AgarPads#13_Pos47/ProcessedData/Position000000.mp4
# Tue Oct 17 00:21:04 2023, Position 0 - Clearing variables from memory
# running position  2023.09.27_Psy_AgarPads#13_Pos49
# Loading configuration from: /Users/jluneau/Documents/Image_analysis/Pseudomonas/2023.09.27_Psy_AgarPads#13/Psy-eGFP/config_2D_local.json
# Initialized experiment reader:
#             - 1 positions
#             - 2 imaging channels
#             - 60 timepoints
# Tue Oct 17 00:21:06 2023, Position 0 - Starting pre-processing
# Tue Oct 17 00:21:06 2023, Position 0 - Starting segmentation (60 frames)
# 64/64 [==============================] - 12s 148ms/step
# 64/64 [==============================] - 9s 147ms/step
# 64/64 [==============================] - 9s 147ms/step
# 48/48 [==============================] - 7s 148ms/step
# Tue Oct 17 00:21:45 2023, Position 0 - Starting tracking (60 frames)
# Tue Oct 17 00:21:45 2023, Position 0 - Tracking - frame 0/60
# Tue Oct 17 00:21:45 2023, Position 0 - Tracking - frame 1/60
# Tue Oct 17 00:21:48 2023, Position 0 - Tracking - frame 2/60
# Tue Oct 17 00:21:48 2023, Position 0 - Tracking - frame 3/60
# Tue Oct 17 00:21:49 2023, Position 0 - Tracking - frame 4/60
# Tue Oct 17 00:21:49 2023, Position 0 - Tracking - frame 5/60
# Tue Oct 17 00:21:49 2023, Position 0 - Tracking - frame 6/60
# Tue Oct 17 00:21:49 2023, Position 0 - Tracking - frame 7/60
# Tue Oct 17 00:21:50 2023, Position 0 - Tracking - frame 8/60
# Tue Oct 17 00:21:50 2023, Position 0 - Tracking - frame 9/60
# Tue Oct 17 00:21:50 2023, Position 0 - Tracking - frame 10/60
# Tue Oct 17 00:21:50 2023, Position 0 - Tracking - frame 11/60
# Tue Oct 17 00:21:51 2023, Position 0 - Tracking - frame 12/60
# Tue Oct 17 00:21:51 2023, Position 0 - Tracking - frame 13/60
# Tue Oct 17 00:21:51 2023, Position 0 - Tracking - frame 14/60
# Tue Oct 17 00:21:52 2023, Position 0 - Tracking - frame 15/60
# Tue Oct 17 00:21:52 2023, Position 0 - Tracking - frame 16/60
# Tue Oct 17 00:21:53 2023, Position 0 - Tracking - frame 17/60
# Tue Oct 17 00:21:53 2023, Position 0 - Tracking - frame 18/60
# Tue Oct 17 00:21:54 2023, Position 0 - Tracking - frame 19/60
# Tue Oct 17 00:21:54 2023, Position 0 - Tracking - frame 20/60
# Tue Oct 17 00:21:55 2023, Position 0 - Tracking - frame 21/60
# Tue Oct 17 00:21:56 2023, Position 0 - Tracking - frame 22/60
# Tue Oct 17 00:21:57 2023, Position 0 - Tracking - frame 23/60
# Tue Oct 17 00:21:58 2023, Position 0 - Tracking - frame 24/60
# Tue Oct 17 00:21:59 2023, Position 0 - Tracking - frame 25/60
# Tue Oct 17 00:22:00 2023, Position 0 - Tracking - frame 26/60
# Tue Oct 17 00:22:01 2023, Position 0 - Tracking - frame 27/60
# Tue Oct 17 00:22:03 2023, Position 0 - Tracking - frame 28/60
# Tue Oct 17 00:22:04 2023, Position 0 - Tracking - frame 29/60
# Tue Oct 17 00:22:06 2023, Position 0 - Tracking - frame 30/60
# Tue Oct 17 00:22:08 2023, Position 0 - Tracking - frame 31/60
# Tue Oct 17 00:22:10 2023, Position 0 - Tracking - frame 32/60
# Tue Oct 17 00:22:12 2023, Position 0 - Tracking - frame 33/60
# Tue Oct 17 00:22:14 2023, Position 0 - Tracking - frame 34/60
# Tue Oct 17 00:22:17 2023, Position 0 - Tracking - frame 35/60
# Tue Oct 17 00:22:19 2023, Position 0 - Tracking - frame 36/60
# Tue Oct 17 00:22:22 2023, Position 0 - Tracking - frame 37/60
# Tue Oct 17 00:22:26 2023, Position 0 - Tracking - frame 38/60
# Tue Oct 17 00:22:29 2023, Position 0 - Tracking - frame 39/60
# Tue Oct 17 00:22:33 2023, Position 0 - Tracking - frame 40/60
# Tue Oct 17 00:22:38 2023, Position 0 - Tracking - frame 41/60
# Tue Oct 17 00:22:42 2023, Position 0 - Tracking - frame 42/60
# Tue Oct 17 00:22:46 2023, Position 0 - Tracking - frame 43/60
# Tue Oct 17 00:22:51 2023, Position 0 - Tracking - frame 44/60
# Tue Oct 17 00:22:55 2023, Position 0 - Tracking - frame 45/60
# Tue Oct 17 00:23:01 2023, Position 0 - Tracking - frame 46/60
# Tue Oct 17 00:23:07 2023, Position 0 - Tracking - frame 47/60
# Tue Oct 17 00:23:13 2023, Position 0 - Tracking - frame 48/60
# Tue Oct 17 00:23:21 2023, Position 0 - Tracking - frame 49/60
# Tue Oct 17 00:23:28 2023, Position 0 - Tracking - frame 50/60
# Tue Oct 17 00:23:36 2023, Position 0 - Tracking - frame 51/60
# Tue Oct 17 00:23:44 2023, Position 0 - Tracking - frame 52/60
# Tue Oct 17 00:23:53 2023, Position 0 - Tracking - frame 53/60
# Tue Oct 17 00:24:01 2023, Position 0 - Tracking - frame 54/60
# Tue Oct 17 00:24:09 2023, Position 0 - Tracking - frame 55/60
# Tue Oct 17 00:24:18 2023, Position 0 - Tracking - frame 56/60
# Tue Oct 17 00:24:27 2023, Position 0 - Tracking - frame 57/60
# Tue Oct 17 00:24:36 2023, Position 0 - Tracking - frame 58/60
# Tue Oct 17 00:24:45 2023, Position 0 - Tracking - frame 59/60
# Tue Oct 17 00:24:56 2023, Position 0 - Starting feature extraction (60 frames)
# Tue Oct 17 00:24:56 2023, Position 0 - Feature extraction - frame 0/60
# Tue Oct 17 00:24:56 2023, Position 0 - Feature extraction - frame 1/60
# Tue Oct 17 00:24:56 2023, Position 0 - Feature extraction - frame 2/60
# Tue Oct 17 00:24:56 2023, Position 0 - Feature extraction - frame 3/60
# Tue Oct 17 00:24:56 2023, Position 0 - Feature extraction - frame 4/60
# Tue Oct 17 00:24:56 2023, Position 0 - Feature extraction - frame 5/60
# Tue Oct 17 00:24:56 2023, Position 0 - Feature extraction - frame 6/60
# Tue Oct 17 00:24:56 2023, Position 0 - Feature extraction - frame 7/60
# Tue Oct 17 00:24:56 2023, Position 0 - Feature extraction - frame 8/60
# Tue Oct 17 00:24:56 2023, Position 0 - Feature extraction - frame 9/60
# Tue Oct 17 00:24:56 2023, Position 0 - Feature extraction - frame 10/60
# Tue Oct 17 00:24:56 2023, Position 0 - Feature extraction - frame 11/60
# Tue Oct 17 00:24:56 2023, Position 0 - Feature extraction - frame 12/60
# Tue Oct 17 00:24:56 2023, Position 0 - Feature extraction - frame 13/60
# Tue Oct 17 00:24:56 2023, Position 0 - Feature extraction - frame 14/60
# Tue Oct 17 00:24:56 2023, Position 0 - Feature extraction - frame 15/60
# Tue Oct 17 00:24:56 2023, Position 0 - Feature extraction - frame 16/60
# Tue Oct 17 00:24:56 2023, Position 0 - Feature extraction - frame 17/60
# Tue Oct 17 00:24:56 2023, Position 0 - Feature extraction - frame 18/60
# Tue Oct 17 00:24:57 2023, Position 0 - Feature extraction - frame 19/60
# Tue Oct 17 00:24:57 2023, Position 0 - Feature extraction - frame 20/60
# Tue Oct 17 00:24:57 2023, Position 0 - Feature extraction - frame 21/60
# Tue Oct 17 00:24:57 2023, Position 0 - Feature extraction - frame 22/60
# Tue Oct 17 00:24:57 2023, Position 0 - Feature extraction - frame 23/60
# Tue Oct 17 00:24:57 2023, Position 0 - Feature extraction - frame 24/60
# Tue Oct 17 00:24:57 2023, Position 0 - Feature extraction - frame 25/60
# Tue Oct 17 00:24:57 2023, Position 0 - Feature extraction - frame 26/60
# Tue Oct 17 00:24:57 2023, Position 0 - Feature extraction - frame 27/60
# Tue Oct 17 00:24:57 2023, Position 0 - Feature extraction - frame 28/60
# Tue Oct 17 00:24:57 2023, Position 0 - Feature extraction - frame 29/60
# Tue Oct 17 00:24:57 2023, Position 0 - Feature extraction - frame 30/60
# Tue Oct 17 00:24:57 2023, Position 0 - Feature extraction - frame 31/60
# Tue Oct 17 00:24:57 2023, Position 0 - Feature extraction - frame 32/60
# Tue Oct 17 00:24:57 2023, Position 0 - Feature extraction - frame 33/60
# Tue Oct 17 00:24:57 2023, Position 0 - Feature extraction - frame 34/60
# Tue Oct 17 00:24:57 2023, Position 0 - Feature extraction - frame 35/60
# Tue Oct 17 00:24:57 2023, Position 0 - Feature extraction - frame 36/60
# Tue Oct 17 00:24:57 2023, Position 0 - Feature extraction - frame 37/60
# Tue Oct 17 00:24:57 2023, Position 0 - Feature extraction - frame 38/60
# Tue Oct 17 00:24:58 2023, Position 0 - Feature extraction - frame 39/60
# Tue Oct 17 00:24:58 2023, Position 0 - Feature extraction - frame 40/60
# Tue Oct 17 00:24:58 2023, Position 0 - Feature extraction - frame 41/60
# Tue Oct 17 00:24:58 2023, Position 0 - Feature extraction - frame 42/60
# Tue Oct 17 00:24:58 2023, Position 0 - Feature extraction - frame 43/60
# Tue Oct 17 00:24:58 2023, Position 0 - Feature extraction - frame 44/60
# Tue Oct 17 00:24:58 2023, Position 0 - Feature extraction - frame 45/60
# Tue Oct 17 00:24:58 2023, Position 0 - Feature extraction - frame 46/60
# Tue Oct 17 00:24:59 2023, Position 0 - Feature extraction - frame 47/60
# Tue Oct 17 00:24:59 2023, Position 0 - Feature extraction - frame 48/60
# Tue Oct 17 00:24:59 2023, Position 0 - Feature extraction - frame 49/60
# Tue Oct 17 00:24:59 2023, Position 0 - Feature extraction - frame 50/60
# Tue Oct 17 00:24:59 2023, Position 0 - Feature extraction - frame 51/60
# Tue Oct 17 00:25:00 2023, Position 0 - Feature extraction - frame 52/60
# Tue Oct 17 00:25:00 2023, Position 0 - Feature extraction - frame 53/60
# Tue Oct 17 00:25:00 2023, Position 0 - Feature extraction - frame 54/60
# Tue Oct 17 00:25:00 2023, Position 0 - Feature extraction - frame 55/60
# Tue Oct 17 00:25:00 2023, Position 0 - Feature extraction - frame 56/60
# Tue Oct 17 00:25:01 2023, Position 0 - Feature extraction - frame 57/60
# Tue Oct 17 00:25:01 2023, Position 0 - Feature extraction - frame 58/60
# Tue Oct 17 00:25:01 2023, Position 0 - Feature extraction - frame 59/60
# Tue Oct 17 00:25:01 2023, Position 0 - Saving to pickle format
# /Users/jluneau/Documents/Image_analysis/Pseudomonas/2023.09.27_Psy_AgarPads#13/Psy-eGFP/2023.09.27_Psy_AgarPads#13_Pos49/ProcessedData/Position000000.pkl
# Tue Oct 17 00:25:02 2023, Position 0 - Saving results movie
# /Users/jluneau/Documents/Image_analysis/Pseudomonas/2023.09.27_Psy_AgarPads#13/Psy-eGFP/2023.09.27_Psy_AgarPads#13_Pos49/ProcessedData/Position000000.mp4
# Tue Oct 17 00:25:10 2023, Position 0 - Clearing variables from memory
# running position  2023.09.27_Psy_AgarPads#13_Pos50
# Loading configuration from: /Users/jluneau/Documents/Image_analysis/Pseudomonas/2023.09.27_Psy_AgarPads#13/Psy-eGFP/config_2D_local.json
# Initialized experiment reader:
#             - 1 positions
#             - 2 imaging channels
#             - 50 timepoints
# Tue Oct 17 00:25:11 2023, Position 0 - Starting pre-processing
# Tue Oct 17 00:25:11 2023, Position 0 - Starting segmentation (50 frames)
# 64/64 [==============================] - 12s 149ms/step
# 64/64 [==============================] - 9s 148ms/step
# 64/64 [==============================] - 9s 148ms/step
# 64/64 [==============================] - 10s 149ms/step
# 64/64 [==============================] - 10s 151ms/step
# 64/64 [==============================] - 10s 151ms/step
# 64/64 [==============================] - 9s 146ms/step
# 2/2 [==============================] - 0s 150ms/step
# Tue Oct 17 00:26:24 2023, Position 0 - Starting tracking (50 frames)
# Tue Oct 17 00:26:24 2023, Position 0 - Tracking - frame 0/50
# Tue Oct 17 00:26:24 2023, Position 0 - Tracking - frame 1/50
# Tue Oct 17 00:26:27 2023, Position 0 - Tracking - frame 2/50
# Tue Oct 17 00:26:27 2023, Position 0 - Tracking - frame 3/50
# Tue Oct 17 00:26:28 2023, Position 0 - Tracking - frame 4/50
# Tue Oct 17 00:26:28 2023, Position 0 - Tracking - frame 5/50
# ...
# Tue Oct 17 00:46:41 2023, Position 0 - Tracking - frame 11/50
# Tue Oct 17 00:46:42 2023, Position 0 - Tracking - frame 12/50
# Tue Oct 17 00:46:42 2023, Position 0 - Tracking - frame 13/50
# Tue Oct 17 00:46:42 2023, Position 0 - Tracking - frame 14/50
# Tue Oct 17 00:46:42 2023, Position 0 - Tracking - frame 15/50
# Tue Oct 17 00:46:43 2023, Position 0 - Tracking - frame 16/50
# Tue Oct 17 00:46:43 2023, Position 0 - Tracking - frame 17/50
# Tue Oct 17 00:46:43 2023, Position 0 - Tracking - frame 18/50
# Tue Oct 17 00:46:44 2023, Position 0 - Tracking - frame 19/50
# Tue Oct 17 00:46:45 2023, Position 0 - Tracking - frame 20/50
# Tue Oct 17 00:46:45 2023, Position 0 - Tracking - frame 21/50
# Tue Oct 17 00:46:46 2023, Position 0 - Tracking - frame 22/50
# Tue Oct 17 00:46:46 2023, Position 0 - Tracking - frame 23/50
# Tue Oct 17 00:46:47 2023, Position 0 - Tracking - frame 24/50
# Tue Oct 17 00:46:48 2023, Position 0 - Tracking - frame 25/50
# Tue Oct 17 00:46:49 2023, Position 0 - Tracking - frame 26/50
# Tue Oct 17 00:46:50 2023, Position 0 - Tracking - frame 27/50
# Tue Oct 17 00:46:51 2023, Position 0 - Tracking - frame 28/50
# Tue Oct 17 00:46:52 2023, Position 0 - Tracking - frame 29/50
# Tue Oct 17 00:46:53 2023, Position 0 - Tracking - frame 30/50
# Tue Oct 17 00:46:55 2023, Position 0 - Tracking - frame 31/50
# Tue Oct 17 00:46:56 2023, Position 0 - Tracking - frame 32/50
# Tue Oct 17 00:46:58 2023, Position 0 - Tracking - frame 33/50
# Tue Oct 17 00:47:00 2023, Position 0 - Tracking - frame 34/50
# Tue Oct 17 00:47:02 2023, Position 0 - Tracking - frame 35/50
# Tue Oct 17 00:47:04 2023, Position 0 - Tracking - frame 36/50
# Tue Oct 17 00:47:06 2023, Position 0 - Tracking - frame 37/50
# Tue Oct 17 00:47:08 2023, Position 0 - Tracking - frame 38/50
# Tue Oct 17 00:47:11 2023, Position 0 - Tracking - frame 39/50
# Tue Oct 17 00:47:14 2023, Position 0 - Tracking - frame 40/50
# Tue Oct 17 00:47:18 2023, Position 0 - Tracking - frame 41/50
# Tue Oct 17 00:47:22 2023, Position 0 - Tracking - frame 42/50
# Tue Oct 17 00:47:26 2023, Position 0 - Tracking - frame 43/50
# Tue Oct 17 00:47:30 2023, Position 0 - Tracking - frame 44/50
# Tue Oct 17 00:47:34 2023, Position 0 - Tracking - frame 45/50
# Tue Oct 17 00:47:38 2023, Position 0 - Tracking - frame 46/50
# Tue Oct 17 00:47:42 2023, Position 0 - Tracking - frame 47/50
# Tue Oct 17 00:47:47 2023, Position 0 - Tracking - frame 48/50
# Tue Oct 17 00:47:52 2023, Position 0 - Tracking - frame 49/50
# Tue Oct 17 00:47:58 2023, Position 0 - Starting feature extraction (50 frames)
# Tue Oct 17 00:47:58 2023, Position 0 - Feature extraction - frame 0/50
# Tue Oct 17 00:47:58 2023, Position 0 - Feature extraction - frame 1/50
# Tue Oct 17 00:47:58 2023, Position 0 - Feature extraction - frame 2/50
# Tue Oct 17 00:47:58 2023, Position 0 - Feature extraction - frame 3/50
# Tue Oct 17 00:47:58 2023, Position 0 - Feature extraction - frame 4/50
# Tue Oct 17 00:47:58 2023, Position 0 - Feature extraction - frame 5/50
# Tue Oct 17 00:47:58 2023, Position 0 - Feature extraction - frame 6/50
# Tue Oct 17 00:47:58 2023, Position 0 - Feature extraction - frame 7/50
# Tue Oct 17 00:47:58 2023, Position 0 - Feature extraction - frame 8/50
# Tue Oct 17 00:47:58 2023, Position 0 - Feature extraction - frame 9/50
# Tue Oct 17 00:47:58 2023, Position 0 - Feature extraction - frame 10/50
# Tue Oct 17 00:47:58 2023, Position 0 - Feature extraction - frame 11/50
# Tue Oct 17 00:47:58 2023, Position 0 - Feature extraction - frame 12/50
# Tue Oct 17 00:47:58 2023, Position 0 - Feature extraction - frame 13/50
# Tue Oct 17 00:47:58 2023, Position 0 - Feature extraction - frame 14/50
# Tue Oct 17 00:47:58 2023, Position 0 - Feature extraction - frame 15/50
# Tue Oct 17 00:47:58 2023, Position 0 - Feature extraction - frame 16/50
# Tue Oct 17 00:47:58 2023, Position 0 - Feature extraction - frame 17/50
# Tue Oct 17 00:47:58 2023, Position 0 - Feature extraction - frame 18/50
# Tue Oct 17 00:47:58 2023, Position 0 - Feature extraction - frame 19/50
# Tue Oct 17 00:47:58 2023, Position 0 - Feature extraction - frame 20/50
# Tue Oct 17 00:47:58 2023, Position 0 - Feature extraction - frame 21/50
# Tue Oct 17 00:47:58 2023, Position 0 - Feature extraction - frame 22/50
# Tue Oct 17 00:47:58 2023, Position 0 - Feature extraction - frame 23/50
# Tue Oct 17 00:47:58 2023, Position 0 - Feature extraction - frame 24/50
# Tue Oct 17 00:47:58 2023, Position 0 - Feature extraction - frame 25/50
# Tue Oct 17 00:47:58 2023, Position 0 - Feature extraction - frame 26/50
# Tue Oct 17 00:47:58 2023, Position 0 - Feature extraction - frame 27/50
# Tue Oct 17 00:47:58 2023, Position 0 - Feature extraction - frame 28/50
# Tue Oct 17 00:47:58 2023, Position 0 - Feature extraction - frame 29/50
# Tue Oct 17 00:47:58 2023, Position 0 - Feature extraction - frame 30/50
# Tue Oct 17 00:47:58 2023, Position 0 - Feature extraction - frame 31/50
# Tue Oct 17 00:47:58 2023, Position 0 - Feature extraction - frame 32/50
# Tue Oct 17 00:47:58 2023, Position 0 - Feature extraction - frame 33/50
# Tue Oct 17 00:47:58 2023, Position 0 - Feature extraction - frame 34/50
# Tue Oct 17 00:47:58 2023, Position 0 - Feature extraction - frame 35/50
# Tue Oct 17 00:47:58 2023, Position 0 - Feature extraction - frame 36/50
# Tue Oct 17 00:47:58 2023, Position 0 - Feature extraction - frame 37/50
# Tue Oct 17 00:47:58 2023, Position 0 - Feature extraction - frame 38/50
# Tue Oct 17 00:47:59 2023, Position 0 - Feature extraction - frame 39/50
# Tue Oct 17 00:47:59 2023, Position 0 - Feature extraction - frame 40/50
# Tue Oct 17 00:47:59 2023, Position 0 - Feature extraction - frame 41/50
# Tue Oct 17 00:47:59 2023, Position 0 - Feature extraction - frame 42/50
# Tue Oct 17 00:47:59 2023, Position 0 - Feature extraction - frame 43/50
# Tue Oct 17 00:47:59 2023, Position 0 - Feature extraction - frame 44/50
# Tue Oct 17 00:47:59 2023, Position 0 - Feature extraction - frame 45/50
# Tue Oct 17 00:47:59 2023, Position 0 - Feature extraction - frame 46/50
# Tue Oct 17 00:47:59 2023, Position 0 - Feature extraction - frame 47/50
# Tue Oct 17 00:47:59 2023, Position 0 - Feature extraction - frame 48/50
# Tue Oct 17 00:47:59 2023, Position 0 - Feature extraction - frame 49/50
# Tue Oct 17 00:48:00 2023, Position 0 - Saving to pickle format
# /Users/jluneau/Documents/Image_analysis/Pseudomonas/2023.09.27_Psy_AgarPads#13/Psy-eGFP/2023.09.27_Psy_AgarPads#13_Pos63/ProcessedData/Position000000.pkl
# Tue Oct 17 00:48:00 2023, Position 0 - Saving results movie
# /Users/jluneau/Documents/Image_analysis/Pseudomonas/2023.09.27_Psy_AgarPads#13/Psy-eGFP/2023.09.27_Psy_AgarPads#13_Pos63/ProcessedData/Position000000.mp4
# Tue Oct 17 00:48:05 2023, Position 0 - Clearing variables from memory
# running position  2023.09.27_Psy_AgarPads#13_Pos69
# Loading configuration from: /Users/jluneau/Documents/Image_analysis/Pseudomonas/2023.09.27_Psy_AgarPads#13/Psy-eGFP/config_2D_local.json
# skipping postion 2023.09.27_Psy_AgarPads#13_Pos69
# running position  2023.09.27_Psy_AgarPads#13_Pos71
#
# systemMemory: 16.00 GB
# maxCacheSize: 5.33 GB
#
# Loading configuration from: /Users/jluneau/Documents/Image_analysis/Pseudomonas/2023.09.27_Psy_AgarPads#13/Psy-eGFP/config_2D_local.json
# skipping postion 2023.09.27_Psy_AgarPads#13_Pos71
# running position  2023.09.27_Psy_AgarPads#13_Pos75
# Loading configuration from: /Users/jluneau/Documents/Image_analysis/Pseudomonas/2023.09.27_Psy_AgarPads#13/Psy-eGFP/config_2D_local.json
# Initialized experiment reader:
#             - 1 positions
#             - 2 imaging channels
#             - 50 timepoints
# [ WARN:0@3316.140] global /Users/runner/miniforge3/conda-bld/libopencv_1658893788286/work/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/Users/jluneau/Documents/Image_analysis/Pseudomonas/2023.09.27_Psy_AgarPads#13/Psy-eGFP/2023.09.27_Psy_AgarPads#13_Pos69/C1-2023.09.27_Psy_AgarPads#13_Pos69_crop0001.tif'): can't open/read file: check file path/integrity
# [ WARN:0@3316.142] global /Users/runner/miniforge3/conda-bld/libopencv_1658893788286/work/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/Users/jluneau/Documents/Image_analysis/Pseudomonas/2023.09.27_Psy_AgarPads#13/Psy-eGFP/2023.09.27_Psy_AgarPads#13_Pos71/C1-2023.09.27_Psy_AgarPads#13_Pos71_crop0001.tif'): can't open/read file: check file path/integrity
# Tue Oct 17 00:48:06 2023, Position 0 - Starting pre-processing
# Tue Oct 17 00:48:06 2023, Position 0 - Starting segmentation (50 frames)
# 64/64 [==============================] - 12s 150ms/step
# 64/64 [==============================] - 10s 150ms/step
# 64/64 [==============================] - 10s 149ms/step
# 64/64 [==============================] - 9s 147ms/step
# 44/44 [==============================] - 7s 150ms/step
# Tue Oct 17 00:48:55 2023, Position 0 - Starting tracking (50 frames)
# Tue Oct 17 00:48:55 2023, Position 0 - Tracking - frame 0/50
# Tue Oct 17 00:48:55 2023, Position 0 - Tracking - frame 1/50
# Tue Oct 17 00:48:58 2023, Position 0 - Tracking - frame 2/50
# Tue Oct 17 00:48:59 2023, Position 0 - Tracking - frame 3/50
# Tue Oct 17 00:48:59 2023, Position 0 - Tracking - frame 4/50
# Tue Oct 17 00:48:59 2023, Position 0 - Tracking - frame 5/50
# Tue Oct 17 00:48:59 2023, Position 0 - Tracking - frame 6/50
# Tue Oct 17 00:49:00 2023, Position 0 - Tracking - frame 7/50
# Tue Oct 17 00:49:00 2023, Position 0 - Tracking - frame 8/50
# Tue Oct 17 00:49:00 2023, Position 0 - Tracking - frame 9/50
# Tue Oct 17 00:49:01 2023, Position 0 - Tracking - frame 10/50
# Tue Oct 17 00:49:01 2023, Position 0 - Tracking - frame 11/50
# Tue Oct 17 00:49:02 2023, Position 0 - Tracking - frame 12/50
# Tue Oct 17 00:49:02 2023, Position 0 - Tracking - frame 13/50
# Tue Oct 17 00:49:03 2023, Position 0 - Tracking - frame 14/50
# Tue Oct 17 00:49:04 2023, Position 0 - Tracking - frame 15/50
# Tue Oct 17 00:49:04 2023, Position 0 - Tracking - frame 16/50
# Tue Oct 17 00:49:05 2023, Position 0 - Tracking - frame 17/50
# Tue Oct 17 00:49:05 2023, Position 0 - Tracking - frame 18/50
# Tue Oct 17 00:49:06 2023, Position 0 - Tracking - frame 19/50
# Tue Oct 17 00:49:07 2023, Position 0 - Tracking - frame 20/50
# Tue Oct 17 00:49:08 2023, Position 0 - Tracking - frame 21/50
# Tue Oct 17 00:49:09 2023, Position 0 - Tracking - frame 22/50
# Tue Oct 17 00:49:10 2023, Position 0 - Tracking - frame 23/50
# Tue Oct 17 00:49:12 2023, Position 0 - Tracking - frame 24/50
# Tue Oct 17 00:49:13 2023, Position 0 - Tracking - frame 25/50
# Tue Oct 17 00:49:14 2023, Position 0 - Tracking - frame 26/50
# Tue Oct 17 00:49:16 2023, Position 0 - Tracking - frame 27/50
# Tue Oct 17 00:49:18 2023, Position 0 - Tracking - frame 28/50
# Tue Oct 17 00:49:20 2023, Position 0 - Tracking - frame 29/50
# Tue Oct 17 00:49:23 2023, Position 0 - Tracking - frame 30/50
# Tue Oct 17 00:49:25 2023, Position 0 - Tracking - frame 31/50
# Tue Oct 17 00:49:27 2023, Position 0 - Tracking - frame 32/50
# Tue Oct 17 00:49:30 2023, Position 0 - Tracking - frame 33/50
# Tue Oct 17 00:49:33 2023, Position 0 - Tracking - frame 34/50
# Tue Oct 17 00:49:36 2023, Position 0 - Tracking - frame 35/50
# Tue Oct 17 00:49:40 2023, Position 0 - Tracking - frame 36/50
# Tue Oct 17 00:49:44 2023, Position 0 - Tracking - frame 37/50
# Tue Oct 17 00:49:49 2023, Position 0 - Tracking - frame 38/50
# Tue Oct 17 00:49:53 2023, Position 0 - Tracking - frame 39/50
# Tue Oct 17 00:49:58 2023, Position 0 - Tracking - frame 40/50
# Tue Oct 17 00:50:03 2023, Position 0 - Tracking - frame 41/50
# Tue Oct 17 00:50:08 2023, Position 0 - Tracking - frame 42/50
# Tue Oct 17 00:50:14 2023, Position 0 - Tracking - frame 43/50
# Tue Oct 17 00:50:21 2023, Position 0 - Tracking - frame 44/50
# Tue Oct 17 00:50:29 2023, Position 0 - Tracking - frame 45/50
# Tue Oct 17 00:50:37 2023, Position 0 - Tracking - frame 46/50
# Tue Oct 17 00:50:46 2023, Position 0 - Tracking - frame 47/50
# Tue Oct 17 00:50:55 2023, Position 0 - Tracking - frame 48/50
# Tue Oct 17 00:51:04 2023, Position 0 - Tracking - frame 49/50
# Tue Oct 17 00:51:13 2023, Position 0 - Starting feature extraction (50 frames)
# Tue Oct 17 00:51:13 2023, Position 0 - Feature extraction - frame 0/50
# Tue Oct 17 00:51:13 2023, Position 0 - Feature extraction - frame 1/50
# Tue Oct 17 00:51:13 2023, Position 0 - Feature extraction - frame 2/50
# Tue Oct 17 00:51:13 2023, Position 0 - Feature extraction - frame 3/50
# Tue Oct 17 00:51:13 2023, Position 0 - Feature extraction - frame 4/50
# Tue Oct 17 00:51:13 2023, Position 0 - Feature extraction - frame 5/50
# Tue Oct 17 00:51:13 2023, Position 0 - Feature extraction - frame 6/50
# Tue Oct 17 00:51:13 2023, Position 0 - Feature extraction - frame 7/50
# Tue Oct 17 00:51:13 2023, Position 0 - Feature extraction - frame 8/50
# Tue Oct 17 00:51:13 2023, Position 0 - Feature extraction - frame 9/50
# Tue Oct 17 00:51:13 2023, Position 0 - Feature extraction - frame 10/50
# Tue Oct 17 00:51:13 2023, Position 0 - Feature extraction - frame 11/50
# Tue Oct 17 00:51:13 2023, Position 0 - Feature extraction - frame 12/50
# Tue Oct 17 00:51:13 2023, Position 0 - Feature extraction - frame 13/50
# Tue Oct 17 00:51:13 2023, Position 0 - Feature extraction - frame 14/50
# Tue Oct 17 00:51:13 2023, Position 0 - Feature extraction - frame 15/50
# Tue Oct 17 00:51:13 2023, Position 0 - Feature extraction - frame 16/50
# Tue Oct 17 00:51:13 2023, Position 0 - Feature extraction - frame 17/50
# Tue Oct 17 00:51:13 2023, Position 0 - Feature extraction - frame 18/50
# Tue Oct 17 00:51:13 2023, Position 0 - Feature extraction - frame 19/50
# Tue Oct 17 00:51:13 2023, Position 0 - Feature extraction - frame 20/50
# Tue Oct 17 00:51:13 2023, Position 0 - Feature extraction - frame 21/50
# Tue Oct 17 00:51:13 2023, Position 0 - Feature extraction - frame 22/50
# Tue Oct 17 00:51:13 2023, Position 0 - Feature extraction - frame 23/50
# Tue Oct 17 00:51:13 2023, Position 0 - Feature extraction - frame 24/50
# Tue Oct 17 00:51:13 2023, Position 0 - Feature extraction - frame 25/50
# Tue Oct 17 00:51:13 2023, Position 0 - Feature extraction - frame 26/50
# Tue Oct 17 00:51:13 2023, Position 0 - Feature extraction - frame 27/50
# Tue Oct 17 00:51:13 2023, Position 0 - Feature extraction - frame 28/50
# Tue Oct 17 00:51:13 2023, Position 0 - Feature extraction - frame 29/50
# Tue Oct 17 00:51:13 2023, Position 0 - Feature extraction - frame 30/50
# Tue Oct 17 00:51:14 2023, Position 0 - Feature extraction - frame 31/50
# Tue Oct 17 00:51:14 2023, Position 0 - Feature extraction - frame 32/50
# Tue Oct 17 00:51:14 2023, Position 0 - Feature extraction - frame 33/50
# Tue Oct 17 00:51:14 2023, Position 0 - Feature extraction - frame 34/50
# Tue Oct 17 00:51:14 2023, Position 0 - Feature extraction - frame 35/50
# Tue Oct 17 00:51:14 2023, Position 0 - Feature extraction - frame 36/50
# Tue Oct 17 00:51:14 2023, Position 0 - Feature extraction - frame 37/50
# Tue Oct 17 00:51:14 2023, Position 0 - Feature extraction - frame 38/50
# Tue Oct 17 00:51:14 2023, Position 0 - Feature extraction - frame 39/50
# Tue Oct 17 00:51:14 2023, Position 0 - Feature extraction - frame 40/50
# Tue Oct 17 00:51:14 2023, Position 0 - Feature extraction - frame 41/50
# Tue Oct 17 00:51:15 2023, Position 0 - Feature extraction - frame 42/50
# Tue Oct 17 00:51:15 2023, Position 0 - Feature extraction - frame 43/50
# Tue Oct 17 00:51:15 2023, Position 0 - Feature extraction - frame 44/50
# Tue Oct 17 00:51:15 2023, Position 0 - Feature extraction - frame 45/50
# Tue Oct 17 00:51:15 2023, Position 0 - Feature extraction - frame 46/50
# Tue Oct 17 00:51:15 2023, Position 0 - Feature extraction - frame 47/50
# Tue Oct 17 00:51:16 2023, Position 0 - Feature extraction - frame 48/50
# Tue Oct 17 00:51:16 2023, Position 0 - Feature extraction - frame 49/50
# Tue Oct 17 00:51:16 2023, Position 0 - Saving to pickle format
# /Users/jluneau/Documents/Image_analysis/Pseudomonas/2023.09.27_Psy_AgarPads#13/Psy-eGFP/2023.09.27_Psy_AgarPads#13_Pos75/ProcessedData/Position000000.pkl
# Tue Oct 17 00:51:16 2023, Position 0 - Saving results movie
# /Users/jluneau/Documents/Image_analysis/Pseudomonas/2023.09.27_Psy_AgarPads#13/Psy-eGFP/2023.09.27_Psy_AgarPads#13_Pos75/ProcessedData/Position000000.mp4
# Tue Oct 17 00:51:22 2023, Position 0 - Clearing variables from memory

# %% [markdown]
# ---

# %% [markdown]
# ## Setup the pipeline for 1 position
#
# Now we setup the pipeline, most importantly, you have to specify the naming format using the `xpreader` function.
# See [here](https://delta.readthedocs.io/en/latest/usage/pipeline_desc.html) for detailed instructions.

# %%
# Set paths
pos_dir = strain_dir / '2023.09.27_Psy_AgarPads#13_Pos71'
data_dir = pos_dir #location of raw data
output_dir = pos_dir / 'ProcessedData' #location of output data
(output_dir).mkdir(exist_ok=True) #create output data folder

# Load config
delta.config.load_config(new_config_filename)

# set path to raw data to analyze:
file_path = to_str(data_dir)

# Init reader and specify file naming scheme
posname = pos_dir.name

xpreader = delta.utils.xpreader(
            file_path,
            prototype = 'C%01i-'+posname+'_crop%04i.tif', #'C%01i-2023.06.14_Psy_AgarPads#5_Pos%01i_crop%04i.tif',
            fileorder = 'ct',
            filenamesindexing=1
            )

# Print experiment parameters to make sure it initialized properly:
print("""Initialized experiment reader:
    - %d positions
    - %d imaging channels
    - %d timepoints"""%(xpreader.positions, xpreader.channels, xpreader.timepoints)
)

# Init pipeline:
xp = delta.pipeline.Pipeline(xpreader, resfolder=output_dir)
# Out:
# Loading configuration from: /Users/jluneau/Documents/Image_analysis/Pseudomonas/2023.09.27_Psy_AgarPads#13/Psy-eGFP/config_2D_local.json
# Initialized experiment reader:
#     - 1 positions
#     - 2 imaging channels
#     - 45 timepoints

# %%
# Run Pipeline
xp.process()
# Out:
# Tue Oct 17 20:29:46 2023, Position 0 - Starting pre-processing
# Tue Oct 17 20:29:46 2023, Position 0 - Starting segmentation (45 frames)
# 64/64 [==============================] - 12s 152ms/step
# 64/64 [==============================] - 9s 147ms/step
# 52/52 [==============================] - 8s 144ms/step
# Tue Oct 17 20:30:17 2023, Position 0 - Starting tracking (45 frames)
# Tue Oct 17 20:30:17 2023, Position 0 - Tracking - frame 0/45
# Tue Oct 17 20:30:17 2023, Position 0 - Tracking - frame 1/45
# Tue Oct 17 20:30:19 2023, Position 0 - Tracking - frame 2/45
# Tue Oct 17 20:30:20 2023, Position 0 - Tracking - frame 3/45
# Tue Oct 17 20:30:20 2023, Position 0 - Tracking - frame 4/45
# Tue Oct 17 20:30:20 2023, Position 0 - Tracking - frame 5/45
# Tue Oct 17 20:30:20 2023, Position 0 - Tracking - frame 6/45
# Tue Oct 17 20:30:21 2023, Position 0 - Tracking - frame 7/45
# Tue Oct 17 20:30:21 2023, Position 0 - Tracking - frame 8/45
# Tue Oct 17 20:30:21 2023, Position 0 - Tracking - frame 9/45
# Tue Oct 17 20:30:21 2023, Position 0 - Tracking - frame 10/45
# Tue Oct 17 20:30:22 2023, Position 0 - Tracking - frame 11/45
# Tue Oct 17 20:30:22 2023, Position 0 - Tracking - frame 12/45
# Tue Oct 17 20:30:23 2023, Position 0 - Tracking - frame 13/45
# Tue Oct 17 20:30:23 2023, Position 0 - Tracking - frame 14/45
# Tue Oct 17 20:30:24 2023, Position 0 - Tracking - frame 15/45
# Tue Oct 17 20:30:25 2023, Position 0 - Tracking - frame 16/45
# Tue Oct 17 20:30:25 2023, Position 0 - Tracking - frame 17/45
# Tue Oct 17 20:30:26 2023, Position 0 - Tracking - frame 18/45
# Tue Oct 17 20:30:26 2023, Position 0 - Tracking - frame 19/45
# Tue Oct 17 20:30:27 2023, Position 0 - Tracking - frame 20/45
# Tue Oct 17 20:30:28 2023, Position 0 - Tracking - frame 21/45
# Tue Oct 17 20:30:29 2023, Position 0 - Tracking - frame 22/45
# Tue Oct 17 20:30:30 2023, Position 0 - Tracking - frame 23/45
# Tue Oct 17 20:30:31 2023, Position 0 - Tracking - frame 24/45
# Tue Oct 17 20:30:32 2023, Position 0 - Tracking - frame 25/45
# Tue Oct 17 20:30:33 2023, Position 0 - Tracking - frame 26/45
# Tue Oct 17 20:30:34 2023, Position 0 - Tracking - frame 27/45
# Tue Oct 17 20:30:36 2023, Position 0 - Tracking - frame 28/45
# Tue Oct 17 20:30:37 2023, Position 0 - Tracking - frame 29/45
# Tue Oct 17 20:30:39 2023, Position 0 - Tracking - frame 30/45
# Tue Oct 17 20:30:42 2023, Position 0 - Tracking - frame 31/45
# Tue Oct 17 20:30:44 2023, Position 0 - Tracking - frame 32/45
# Tue Oct 17 20:30:46 2023, Position 0 - Tracking - frame 33/45
# Tue Oct 17 20:30:48 2023, Position 0 - Tracking - frame 34/45
# Tue Oct 17 20:30:50 2023, Position 0 - Tracking - frame 35/45
# Tue Oct 17 20:30:54 2023, Position 0 - Tracking - frame 36/45
# Tue Oct 17 20:30:57 2023, Position 0 - Tracking - frame 37/45
# Tue Oct 17 20:31:02 2023, Position 0 - Tracking - frame 38/45
# Tue Oct 17 20:31:05 2023, Position 0 - Tracking - frame 39/45
# Tue Oct 17 20:31:10 2023, Position 0 - Tracking - frame 40/45
# Tue Oct 17 20:31:14 2023, Position 0 - Tracking - frame 41/45
# Tue Oct 17 20:31:19 2023, Position 0 - Tracking - frame 42/45
# Tue Oct 17 20:31:24 2023, Position 0 - Tracking - frame 43/45
# Tue Oct 17 20:31:30 2023, Position 0 - Tracking - frame 44/45
# Tue Oct 17 20:31:36 2023, Position 0 - Starting feature extraction (45 frames)
# Tue Oct 17 20:31:36 2023, Position 0 - Feature extraction - frame 0/45
# Tue Oct 17 20:31:36 2023, Position 0 - Feature extraction - frame 1/45
# Tue Oct 17 20:31:36 2023, Position 0 - Feature extraction - frame 2/45
# Tue Oct 17 20:31:36 2023, Position 0 - Feature extraction - frame 3/45
# Tue Oct 17 20:31:36 2023, Position 0 - Feature extraction - frame 4/45
# Tue Oct 17 20:31:36 2023, Position 0 - Feature extraction - frame 5/45
# Tue Oct 17 20:31:36 2023, Position 0 - Feature extraction - frame 6/45
# Tue Oct 17 20:31:36 2023, Position 0 - Feature extraction - frame 7/45
# Tue Oct 17 20:31:36 2023, Position 0 - Feature extraction - frame 8/45
# Tue Oct 17 20:31:36 2023, Position 0 - Feature extraction - frame 9/45
# Tue Oct 17 20:31:36 2023, Position 0 - Feature extraction - frame 10/45
# Tue Oct 17 20:31:36 2023, Position 0 - Feature extraction - frame 11/45
# Tue Oct 17 20:31:36 2023, Position 0 - Feature extraction - frame 12/45
# Tue Oct 17 20:31:36 2023, Position 0 - Feature extraction - frame 13/45
# Tue Oct 17 20:31:36 2023, Position 0 - Feature extraction - frame 14/45
# Tue Oct 17 20:31:36 2023, Position 0 - Feature extraction - frame 15/45
# Tue Oct 17 20:31:36 2023, Position 0 - Feature extraction - frame 16/45
# Tue Oct 17 20:31:36 2023, Position 0 - Feature extraction - frame 17/45
# Tue Oct 17 20:31:36 2023, Position 0 - Feature extraction - frame 18/45
# Tue Oct 17 20:31:36 2023, Position 0 - Feature extraction - frame 19/45
# Tue Oct 17 20:31:36 2023, Position 0 - Feature extraction - frame 20/45
# Tue Oct 17 20:31:36 2023, Position 0 - Feature extraction - frame 21/45
# Tue Oct 17 20:31:36 2023, Position 0 - Feature extraction - frame 22/45
# Tue Oct 17 20:31:36 2023, Position 0 - Feature extraction - frame 23/45
# Tue Oct 17 20:31:36 2023, Position 0 - Feature extraction - frame 24/45
# Tue Oct 17 20:31:36 2023, Position 0 - Feature extraction - frame 25/45
# Tue Oct 17 20:31:36 2023, Position 0 - Feature extraction - frame 26/45
# Tue Oct 17 20:31:36 2023, Position 0 - Feature extraction - frame 27/45
# Tue Oct 17 20:31:36 2023, Position 0 - Feature extraction - frame 28/45
# Tue Oct 17 20:31:36 2023, Position 0 - Feature extraction - frame 29/45
# Tue Oct 17 20:31:36 2023, Position 0 - Feature extraction - frame 30/45
# Tue Oct 17 20:31:37 2023, Position 0 - Feature extraction - frame 31/45
# Tue Oct 17 20:31:37 2023, Position 0 - Feature extraction - frame 32/45
# Tue Oct 17 20:31:37 2023, Position 0 - Feature extraction - frame 33/45
# Tue Oct 17 20:31:37 2023, Position 0 - Feature extraction - frame 34/45
# Tue Oct 17 20:31:37 2023, Position 0 - Feature extraction - frame 35/45
# Tue Oct 17 20:31:37 2023, Position 0 - Feature extraction - frame 36/45
# Tue Oct 17 20:31:37 2023, Position 0 - Feature extraction - frame 37/45
# Tue Oct 17 20:31:37 2023, Position 0 - Feature extraction - frame 38/45
# Tue Oct 17 20:31:37 2023, Position 0 - Feature extraction - frame 39/45
# Tue Oct 17 20:31:37 2023, Position 0 - Feature extraction - frame 40/45
# Tue Oct 17 20:31:37 2023, Position 0 - Feature extraction - frame 41/45
# Tue Oct 17 20:31:37 2023, Position 0 - Feature extraction - frame 42/45
# Tue Oct 17 20:31:37 2023, Position 0 - Feature extraction - frame 43/45
# Tue Oct 17 20:31:37 2023, Position 0 - Feature extraction - frame 44/45
# Tue Oct 17 20:31:38 2023, Position 0 - Saving to pickle format
# /Users/jluneau/Documents/Image_analysis/Pseudomonas/2023.09.27_Psy_AgarPads#13/Psy-eGFP/2023.09.27_Psy_AgarPads#13_Pos71/ProcessedData/Position000000.pkl
# Tue Oct 17 20:31:38 2023, Position 0 - Saving results movie
# /Users/jluneau/Documents/Image_analysis/Pseudomonas/2023.09.27_Psy_AgarPads#13/Psy-eGFP/2023.09.27_Psy_AgarPads#13_Pos71/ProcessedData/Position000000.mp4
# Tue Oct 17 20:31:42 2023, Position 0 - Clearing variables from memory
